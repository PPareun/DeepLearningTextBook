# %% [markdown]
# # Variational autoencoder

# %%
pip install --upgrade gdown
# Out:
# Collecting gdown
#   Downloading https://files.pythonhosted.org/packages/52/b9/d426f164f35bb50d512a77d6a7c5eb70b2bea3459dc10f73f130ba732810/gdown-3.13.0.tar.gz
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# Requirement already satisfied, skipping upgrade: tqdm in /usr/local/lib/python3.7/dist-packages (from gdown) (4.41.1)
# Requirement already satisfied, skipping upgrade: filelock in /usr/local/lib/python3.7/dist-packages (from gdown) (3.0.12)
# Requirement already satisfied, skipping upgrade: requests[socks]>=2.12.0 in /usr/local/lib/python3.7/dist-packages (from gdown) (2.23.0)
# Requirement already satisfied, skipping upgrade: six in /usr/local/lib/python3.7/dist-packages (from gdown) (1.15.0)
# Requirement already satisfied, skipping upgrade: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests[socks]>=2.12.0->gdown) (1.24.3)
# Requirement already satisfied, skipping upgrade: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests[socks]>=2.12.0->gdown) (2.10)
# Requirement already satisfied, skipping upgrade: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests[socks]>=2.12.0->gdown) (2021.5.30)
# Requirement already satisfied, skipping upgrade: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests[socks]>=2.12.0->gdown) (3.0.4)
# Requirement already satisfied, skipping upgrade: PySocks!=1.5.7,>=1.5.6; extra == "socks" in /usr/local/lib/python3.7/dist-packages (from requests[socks]>=2.12.0->gdown) (1.7.1)
# Building wheels for collected packages: gdown
#   Building wheel for gdown (PEP 517) ... done
#   Created wheel for gdown: filename=gdown-3.13.0-cp37-none-any.whl size=9046 sha256=7a77d001dbedee73e3d9b9687b5e37c4cd122e0c30a67ca26f27cc6adcc1c330
#   Stored in directory: /root/.cache/pip/wheels/ba/fa/c5/12813d7496f34652c43a471e11a780e769889d06e34735c32e
# Successfully built gdown
# Installing collected packages: gdown
#   Found existing installation: gdown 3.6.4
#     Uninstalling gdown-3.6.4:
#       Successfully uninstalled gdown-3.6.4
# Successfully installed gdown-3.13.0

# %%
pip install google-colab
# Out:
# Requirement already satisfied: google-colab in /usr/local/lib/python3.7/dist-packages (1.0.0)
# Requirement already satisfied: ipython~=5.5.0 in /usr/local/lib/python3.7/dist-packages (from google-colab) (5.5.0)
# Requirement already satisfied: tornado~=5.1.0; python_version >= "3.0" in /usr/local/lib/python3.7/dist-packages (from google-colab) (5.1.1)
# Requirement already satisfied: notebook~=5.3.0; python_version >= "3.0" in /usr/local/lib/python3.7/dist-packages (from google-colab) (5.3.1)
# Requirement already satisfied: astor~=0.8.1 in /usr/local/lib/python3.7/dist-packages (from google-colab) (0.8.1)
# Requirement already satisfied: six~=1.15.0 in /usr/local/lib/python3.7/dist-packages (from google-colab) (1.15.0)
# Requirement already satisfied: portpicker~=1.3.1 in /usr/local/lib/python3.7/dist-packages (from google-colab) (1.3.9)
# Requirement already satisfied: google-auth>=1.17.2 in /usr/local/lib/python3.7/dist-packages (from google-colab) (1.32.1)
# Requirement already satisfied: pandas~=1.1.0; python_version >= "3.0" in /usr/local/lib/python3.7/dist-packages (from google-colab) (1.1.5)
# Requirement already satisfied: ipykernel~=4.10 in /usr/local/lib/python3.7/dist-packages (from google-colab) (4.10.1)
# Requirement already satisfied: requests~=2.23.0 in /usr/local/lib/python3.7/dist-packages (from google-colab) (2.23.0)
# Requirement already satisfied: traitlets>=4.2 in /usr/local/lib/python3.7/dist-packages (from ipython~=5.5.0->google-colab) (5.0.5)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.7/dist-packages (from ipython~=5.5.0->google-colab) (0.7.5)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.7/dist-packages (from ipython~=5.5.0->google-colab) (57.0.0)
# Requirement already satisfied: prompt-toolkit<2.0.0,>=1.0.4 in /usr/local/lib/python3.7/dist-packages (from ipython~=5.5.0->google-colab) (1.0.18)
# Requirement already satisfied: pygments in /usr/local/lib/python3.7/dist-packages (from ipython~=5.5.0->google-colab) (2.6.1)
# Requirement already satisfied: simplegeneric>0.8 in /usr/local/lib/python3.7/dist-packages (from ipython~=5.5.0->google-colab) (0.8.1)
# Requirement already satisfied: decorator in /usr/local/lib/python3.7/dist-packages (from ipython~=5.5.0->google-colab) (4.4.2)
# Requirement already satisfied: pexpect; sys_platform != "win32" in /usr/local/lib/python3.7/dist-packages (from ipython~=5.5.0->google-colab) (4.8.0)
# Requirement already satisfied: ipython-genutils in /usr/local/lib/python3.7/dist-packages (from notebook~=5.3.0; python_version >= "3.0"->google-colab) (0.2.0)
# Requirement already satisfied: terminado>=0.8.1 in /usr/local/lib/python3.7/dist-packages (from notebook~=5.3.0; python_version >= "3.0"->google-colab) (0.10.1)
# Requirement already satisfied: Send2Trash in /usr/local/lib/python3.7/dist-packages (from notebook~=5.3.0; python_version >= "3.0"->google-colab) (1.7.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.7/dist-packages (from notebook~=5.3.0; python_version >= "3.0"->google-colab) (2.11.3)
# Requirement already satisfied: jupyter-client>=5.2.0 in /usr/local/lib/python3.7/dist-packages (from notebook~=5.3.0; python_version >= "3.0"->google-colab) (5.3.5)
# Requirement already satisfied: nbformat in /usr/local/lib/python3.7/dist-packages (from notebook~=5.3.0; python_version >= "3.0"->google-colab) (5.1.3)
# Requirement already satisfied: jupyter-core>=4.4.0 in /usr/local/lib/python3.7/dist-packages (from notebook~=5.3.0; python_version >= "3.0"->google-colab) (4.7.1)
# Requirement already satisfied: nbconvert in /usr/local/lib/python3.7/dist-packages (from notebook~=5.3.0; python_version >= "3.0"->google-colab) (5.6.1)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from google-auth>=1.17.2->google-colab) (4.2.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from google-auth>=1.17.2->google-colab) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4; python_version >= "3.6" in /usr/local/lib/python3.7/dist-packages (from google-auth>=1.17.2->google-colab) (4.7.2)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.7/dist-packages (from pandas~=1.1.0; python_version >= "3.0"->google-colab) (2018.9)
# Requirement already satisfied: numpy>=1.15.4 in /usr/local/lib/python3.7/dist-packages (from pandas~=1.1.0; python_version >= "3.0"->google-colab) (1.19.5)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas~=1.1.0; python_version >= "3.0"->google-colab) (2.8.1)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests~=2.23.0->google-colab) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests~=2.23.0->google-colab) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests~=2.23.0->google-colab) (2021.5.30)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests~=2.23.0->google-colab) (1.24.3)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.7/dist-packages (from prompt-toolkit<2.0.0,>=1.0.4->ipython~=5.5.0->google-colab) (0.2.5)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.7/dist-packages (from pexpect; sys_platform != "win32"->ipython~=5.5.0->google-colab) (0.7.0)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.7/dist-packages (from jinja2->notebook~=5.3.0; python_version >= "3.0"->google-colab) (2.0.1)
# Requirement already satisfied: pyzmq>=13 in /usr/local/lib/python3.7/dist-packages (from jupyter-client>=5.2.0->notebook~=5.3.0; python_version >= "3.0"->google-colab) (22.1.0)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in /usr/local/lib/python3.7/dist-packages (from nbformat->notebook~=5.3.0; python_version >= "3.0"->google-colab) (2.6.0)
# Requirement already satisfied: mistune<2,>=0.8.1 in /usr/local/lib/python3.7/dist-packages (from nbconvert->notebook~=5.3.0; python_version >= "3.0"->google-colab) (0.8.4)
# Requirement already satisfied: entrypoints>=0.2.2 in /usr/local/lib/python3.7/dist-packages (from nbconvert->notebook~=5.3.0; python_version >= "3.0"->google-colab) (0.3)
# Requirement already satisfied: testpath in /usr/local/lib/python3.7/dist-packages (from nbconvert->notebook~=5.3.0; python_version >= "3.0"->google-colab) (0.5.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.7/dist-packages (from nbconvert->notebook~=5.3.0; python_version >= "3.0"->google-colab) (1.4.3)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.7/dist-packages (from nbconvert->notebook~=5.3.0; python_version >= "3.0"->google-colab) (0.7.1)
# Requirement already satisfied: bleach in /usr/local/lib/python3.7/dist-packages (from nbconvert->notebook~=5.3.0; python_version >= "3.0"->google-colab) (3.3.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.7/dist-packages (from pyasn1-modules>=0.2.1->google-auth>=1.17.2->google-colab) (0.4.8)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.7/dist-packages (from bleach->nbconvert->notebook~=5.3.0; python_version >= "3.0"->google-colab) (0.5.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from bleach->nbconvert->notebook~=5.3.0; python_version >= "3.0"->google-colab) (20.9)
# Requirement already satisfied: pyparsing>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->bleach->nbconvert->notebook~=5.3.0; python_version >= "3.0"->google-colab) (2.4.7)

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# !ln -s /content/gdrive/My\ Drive/ /mydrive
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# **CelebA dataset**
# 공식 구글 드라이브가 사용용량으로 다운로드가 불가능한 경우가 있습니다.
# 미러 링크 등을 이용하시면 됩니다.

# %%
import gdown
md5 = '00d2c5bc6d35e252742224ab0c1e8fcb'  
# official download link
url = 'https://drive.google.com/uc?id=0B7EVK8r0v71pZjFTYXZWM3FlRnM'
# mirror url
url = 'https://drive.google.com/uc?id=1vsObPMdbOQwysIb-XulliKXqRSKrw6Iq'
output = '/mydrive/img_align_celeba.zip'
# output = 'img_align_celeba.zip'
gdown.cached_download(url, output, md5=md5)
# Out:
# Computing MD5: /mydrive/img_align_celeba.zip
# MD5 matches: /mydrive/img_align_celeba.zip
# '/mydrive/img_align_celeba.zip'

# %% [markdown]
# CelebA attribute data

# %%
import gdown
md5 = '4414d5bdd90f37e4a8548c501e098835'  
# official download link
url = 'https://drive.google.com/uc?id=1epcRzi5e2IzuWhAMNaigYtyRhwUq72-2'
# output = '/mydrive/list_attr_celeba.csv'
output = 'list_attr_celeba.csv'
gdown.cached_download(url, output, md5=md5)
# Out:
# Cached Downloading: list_attr_celeba.csv
# Downloading...
# From: https://drive.google.com/uc?id=1epcRzi5e2IzuWhAMNaigYtyRhwUq72-2
# To: /root/.cache/gdown/tmp9phcwhdb/dl
# 24.7MB [00:00, 121MB/s]
# Computing MD5: list_attr_celeba.csv
# MD5 matches: list_attr_celeba.csv
# 'list_attr_celeba.csv'

# %%
# !mkdir -p vae_data/celeb
# !mkdir -p vae_data/weights

# %%
# !unzip /mydrive/img_align_celeba.zip -d vae_data/celeb
# !unzip img_align_celeba.zip -d vae_data/celeb
# Out:
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
#  extracting: vae_data/celeb/img_align_celeba/197600.jpg
#  extracting: vae_data/celeb/img_align_celeba/197601.jpg
#  extracting: vae_data/celeb/img_align_celeba/197602.jpg
#  extracting: vae_data/celeb/img_align_celeba/197603.jpg
#  extracting: vae_data/celeb/img_align_celeba/197604.jpg
#  extracting: vae_data/celeb/img_align_celeba/197605.jpg
#  extracting: vae_data/celeb/img_align_celeba/197606.jpg
#  extracting: vae_data/celeb/img_align_celeba/197607.jpg
#  extracting: vae_data/celeb/img_align_celeba/197608.jpg
#  extracting: vae_data/celeb/img_align_celeba/197609.jpg
#  extracting: vae_data/celeb/img_align_celeba/197610.jpg
#  extracting: vae_data/celeb/img_align_celeba/197611.jpg
#  extracting: vae_data/celeb/img_align_celeba/197612.jpg
#  extracting: vae_data/celeb/img_align_celeba/197613.jpg
#  extracting: vae_data/celeb/img_align_celeba/197614.jpg
#  extracting: vae_data/celeb/img_align_celeba/197615.jpg
#  extracting: vae_data/celeb/img_align_celeba/197616.jpg
#  extracting: vae_data/celeb/img_align_celeba/197617.jpg
#  extracting: vae_data/celeb/img_align_celeba/197618.jpg
#  extracting: vae_data/celeb/img_align_celeba/197619.jpg
#  extracting: vae_data/celeb/img_align_celeba/197620.jpg
#  extracting: vae_data/celeb/img_align_celeba/197621.jpg
#  extracting: vae_data/celeb/img_align_celeba/197622.jpg
#  extracting: vae_data/celeb/img_align_celeba/197623.jpg
#  extracting: vae_data/celeb/img_align_celeba/197624.jpg
#  extracting: vae_data/celeb/img_align_celeba/197625.jpg
#  extracting: vae_data/celeb/img_align_celeba/197626.jpg
#  extracting: vae_data/celeb/img_align_celeba/197627.jpg
#  extracting: vae_data/celeb/img_align_celeba/197628.jpg
#  extracting: vae_data/celeb/img_align_celeba/197629.jpg
#  extracting: vae_data/celeb/img_align_celeba/197630.jpg
#  extracting: vae_data/celeb/img_align_celeba/197631.jpg
#  extracting: vae_data/celeb/img_align_celeba/197632.jpg
#  extracting: vae_data/celeb/img_align_celeba/197633.jpg
#  extracting: vae_data/celeb/img_align_celeba/197634.jpg
#  extracting: vae_data/celeb/img_align_celeba/197635.jpg
#  extracting: vae_data/celeb/img_align_celeba/197636.jpg
#  extracting: vae_data/celeb/img_align_celeba/197637.jpg
#  extracting: vae_data/celeb/img_align_celeba/197638.jpg
#  extracting: vae_data/celeb/img_align_celeba/197639.jpg
#  extracting: vae_data/celeb/img_align_celeba/197640.jpg
#  extracting: vae_data/celeb/img_align_celeba/197641.jpg
#  extracting: vae_data/celeb/img_align_celeba/197642.jpg
#  extracting: vae_data/celeb/img_align_celeba/202569.jpg
#  extracting: vae_data/celeb/img_align_celeba/202570.jpg
#  extracting: vae_data/celeb/img_align_celeba/202571.jpg
#  extracting: vae_data/celeb/img_align_celeba/202572.jpg
#  extracting: vae_data/celeb/img_align_celeba/202573.jpg
#  extracting: vae_data/celeb/img_align_celeba/202574.jpg
#  extracting: vae_data/celeb/img_align_celeba/202575.jpg
#  extracting: vae_data/celeb/img_align_celeba/202576.jpg
#  extracting: vae_data/celeb/img_align_celeba/202577.jpg
#  extracting: vae_data/celeb/img_align_celeba/202578.jpg
#  extracting: vae_data/celeb/img_align_celeba/202579.jpg
#  extracting: vae_data/celeb/img_align_celeba/202580.jpg
#  extracting: vae_data/celeb/img_align_celeba/202581.jpg
#  extracting: vae_data/celeb/img_align_celeba/202582.jpg
#  extracting: vae_data/celeb/img_align_celeba/202583.jpg
#  extracting: vae_data/celeb/img_align_celeba/202584.jpg
#  extracting: vae_data/celeb/img_align_celeba/202585.jpg
#  extracting: vae_data/celeb/img_align_celeba/202586.jpg
#  extracting: vae_data/celeb/img_align_celeba/202587.jpg
#  extracting: vae_data/celeb/img_align_celeba/202588.jpg
#  extracting: vae_data/celeb/img_align_celeba/202589.jpg
#  extracting: vae_data/celeb/img_align_celeba/202590.jpg
#  extracting: vae_data/celeb/img_align_celeba/202591.jpg
#  extracting: vae_data/celeb/img_align_celeba/202592.jpg
#  extracting: vae_data/celeb/img_align_celeba/202593.jpg
#  extracting: vae_data/celeb/img_align_celeba/202594.jpg
#  extracting: vae_data/celeb/img_align_celeba/202595.jpg
#  extracting: vae_data/celeb/img_align_celeba/202596.jpg
#  extracting: vae_data/celeb/img_align_celeba/202597.jpg
#  extracting: vae_data/celeb/img_align_celeba/202598.jpg
#  extracting: vae_data/celeb/img_align_celeba/202599.jpg

# %%
# !cp /mydrive/list_attr_celeba.csv vae_data/celeb
# !cp list_attr_celeba.csv vae_data/celeb

# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.layers import Conv2D, LeakyReLU, Flatten
from tensorflow.keras.layers import Dense, Conv2DTranspose
from tensorflow.keras.layers import Reshape, Activation
from tensorflow.keras.layers import BatchNormalization, Dropout
from tensorflow.keras import backend as K
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import LearningRateScheduler
import os
from glob import glob

# %%
SAVE_FOLDER = 'vae_data'
DATA_FOLDER = SAVE_FOLDER + '/celeb/'

INPUT_DIM = (128,128,3)
BATCH_SIZE = 32

filenames = np.array(glob(os.path.join(DATA_FOLDER, '*/*.jpg')))

NUM_IMAGES = len(filenames)

mode =  'build' #'load' #
#mode =  'load'

# %% [markdown]
# **학습용 Data Generator**

# %%
data_gen = ImageDataGenerator(rescale=1./255)

data_flow = data_gen.flow_from_directory(DATA_FOLDER
                                         , target_size = INPUT_DIM[:2]
                                         , batch_size = BATCH_SIZE
                                         , shuffle = True
                                         , class_mode = 'input'
                                         , subset = "training"
                                            )
# Out:
# Found 202599 images belonging to 1 classes.

# %% [markdown]
# **Sampling 레이어**
# standard normal distritubion인 $\epsilon$ 샘플링으로부터
# $\mu$와 $\sigma$의 정규분포를 생성하는 레이어
# $ N(\mu, \sigma) = \mu + \sigma N(0, 1) = \mu + \sigma\epsilon$

# %%
class Sampling(layers.Layer):
    """Uses (mu, log_var) to sample z, the vector encoding a digit."""

    def call(self, inputs):
        mu, log_var = inputs
        batch = tf.shape(mu)[0]
        dim = tf.shape(mu)[1]
        epsilon = tf.keras.backend.random_normal(shape=(batch, dim))
        return mu + tf.exp(log_var/2) * epsilon

# %% [markdown]
# **Encoder 모델 정의**
# Latent space의 차원: 200

# %%
z_dim = 200
r_loss_factor = 10000

encoder_input = keras.Input(shape=INPUT_DIM, name='encoder_input')
x = Conv2D(32, 3, strides=2, padding="same", name='encoder_conv_0')(encoder_input)
x = BatchNormalization()(x)
x = LeakyReLU()(x)
x = Conv2D(64, 3, strides=2, padding="same", name='encoder_conv_1')(x)
x = BatchNormalization()(x)
x = LeakyReLU()(x)
x = Dropout(rate = 0.25)(x)
x = Conv2D(64, 3, strides=2, padding="same", name='encoder_conv_2')(x)
x = BatchNormalization()(x)
x = LeakyReLU()(x)
x = Dropout(rate = 0.25)(x)
x = Conv2D(64, 3, strides=2, padding="same", name='encoder_conv_3')(x)
x = BatchNormalization()(x)
x = LeakyReLU()(x)
x = Dropout(rate = 0.25)(x)
shape_before_flattening = K.int_shape(x)[1:]
x = Flatten()(x)
mu = Dense(z_dim, name='mu')(x)
log_var = Dense(z_dim, name='log_var')(x)
z = Sampling(name='encoder_output')([mu, log_var])
encoder = keras.Model(encoder_input, [mu, log_var, z], name = 'encoder')
encoder.summary()
# Out:
# Model: "encoder"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# encoder_input (InputLayer)      [(None, 128, 128, 3) 0
# __________________________________________________________________________________________________
# encoder_conv_0 (Conv2D)         (None, 64, 64, 32)   896         encoder_input[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 64, 64, 32)   128         encoder_conv_0[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu (LeakyReLU)         (None, 64, 64, 32)   0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# encoder_conv_1 (Conv2D)         (None, 32, 32, 64)   18496       leaky_re_lu[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 32, 32, 64)   256         encoder_conv_1[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_1 (LeakyReLU)       (None, 32, 32, 64)   0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 32, 32, 64)   0           leaky_re_lu_1[0][0]
# __________________________________________________________________________________________________
# encoder_conv_2 (Conv2D)         (None, 16, 16, 64)   36928       dropout[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 16, 16, 64)   256         encoder_conv_2[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_2 (LeakyReLU)       (None, 16, 16, 64)   0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 16, 16, 64)   0           leaky_re_lu_2[0][0]
# __________________________________________________________________________________________________
# encoder_conv_3 (Conv2D)         (None, 8, 8, 64)     36928       dropout_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 8, 8, 64)     256         encoder_conv_3[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_3 (LeakyReLU)       (None, 8, 8, 64)     0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 8, 8, 64)     0           leaky_re_lu_3[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 4096)         0           dropout_2[0][0]
# __________________________________________________________________________________________________
# mu (Dense)                      (None, 200)          819400      flatten[0][0]
# __________________________________________________________________________________________________
# log_var (Dense)                 (None, 200)          819400      flatten[0][0]
# __________________________________________________________________________________________________
# encoder_output (Sampling)       (None, 200)          0           mu[0][0]
#                                                                  log_var[0][0]
# ==================================================================================================
# Total params: 1,732,944
# Trainable params: 1,732,496
# Non-trainable params: 448
# __________________________________________________________________________________________________

# %% [markdown]
# **Decoder 모델 정의**

# %%
decoder_input = keras.Input(shape=(z_dim,), name='decoder_input')
x = Dense(np.prod(shape_before_flattening))(decoder_input)
x = Reshape(shape_before_flattening)(x)
x = layers.Conv2DTranspose(64, 3, strides=2, padding="same", name='decoder_conv_t0')(x)
x = BatchNormalization()(x)
x = LeakyReLU()(x)
x = Dropout(rate = 0.25)(x)
x = layers.Conv2DTranspose(64, 3, strides=2, padding="same", name='decoder_conv_t1')(x)
x = BatchNormalization()(x)
x = LeakyReLU()(x)
x = Dropout(rate = 0.25)(x)
x = layers.Conv2DTranspose(32, 3, strides=2, padding="same", name='decoder_conv_t2')(x)
x = BatchNormalization()(x)
x = LeakyReLU()(x)
x = Dropout(rate = 0.25)(x)
x = layers.Conv2DTranspose(3, 3, strides=2, padding="same", name='decoder_conv_t3')(x)
decoder_output = Activation('sigmoid')(x)
decoder = keras.Model(decoder_input, decoder_output, name="decoder")
decoder.summary()
# Out:
# Model: "decoder"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# decoder_input (InputLayer)   [(None, 200)]             0
# _________________________________________________________________
# dense (Dense)                (None, 4096)              823296
# _________________________________________________________________
# reshape (Reshape)            (None, 8, 8, 64)          0
# _________________________________________________________________
# decoder_conv_t0 (Conv2DTrans (None, 16, 16, 64)        36928
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 16, 16, 64)        256
# _________________________________________________________________
# leaky_re_lu_4 (LeakyReLU)    (None, 16, 16, 64)        0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 16, 16, 64)        0
# _________________________________________________________________
# decoder_conv_t1 (Conv2DTrans (None, 32, 32, 64)        36928
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 32, 32, 64)        256
# _________________________________________________________________
# leaky_re_lu_5 (LeakyReLU)    (None, 32, 32, 64)        0
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 32, 32, 64)        0
# _________________________________________________________________
# decoder_conv_t2 (Conv2DTrans (None, 64, 64, 32)        18464
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 64, 64, 32)        128
# _________________________________________________________________
# leaky_re_lu_6 (LeakyReLU)    (None, 64, 64, 32)        0
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 64, 64, 32)        0
# _________________________________________________________________
# decoder_conv_t3 (Conv2DTrans (None, 128, 128, 3)       867
# _________________________________________________________________
# activation (Activation)      (None, 128, 128, 3)       0
# =================================================================
# Total params: 917,123
# Trainable params: 916,803
# Non-trainable params: 320
# _________________________________________________________________

# %% [markdown]
# **Variational Autoencoder 모델 정의**
# `keras.Model` 클래스를 상속받아서 새로 정의함
#
# $D_{KL}(p\parallel q)={1\over 2}\left(\sigma^2+\mu^2-2\log\sigma-1 \right )$

# %%
class VAEModel(keras.Model):
    def __init__(self, encoder, decoder, **kwargs):
        super(VAEModel, self).__init__(**kwargs)
        self.encoder = encoder
        self.decoder = decoder
        #self.r_loss_factor = r_loss_factor

    def train_step(self, data):
        if isinstance(data, tuple):
            data = data[0]
        with tf.GradientTape() as tape:
            z_mean, z_log_var, z = self.encoder(data)
            reconstruction = self.decoder(z)
            reconstruction_loss = tf.reduce_mean(
                #tf.square(data - reconstruction)
                keras.losses.binary_crossentropy(data, reconstruction)
            )
            reconstruction_loss *= r_loss_factor
            kl_loss = 1 + z_log_var - tf.square(z_mean) - tf.exp(z_log_var)
            kl_loss = tf.reduce_mean(tf.reduce_sum(kl_loss, axis=1))
            kl_loss *= -0.5
            total_loss = reconstruction_loss + kl_loss
        grads = tape.gradient(total_loss, self.trainable_weights)
        self.optimizer.apply_gradients(zip(grads, self.trainable_weights))
        return {
            "loss": tf.reduce_mean(total_loss),
            "reconstruction_loss": tf.reduce_mean(reconstruction_loss),
            "kl_loss": tf.reduce_mean(kl_loss),
        }

    def call(self,inputs):
        _,_,latent = self.encoder(inputs)
        return self.decoder(latent)

# %%
LEARNING_RATE = 0.0005
EPOCHS = 200
PRINT_EVERY_N_BATCHES = 100
INITIAL_EPOCH = 0

save_folder = os.path.join(SAVE_FOLDER, 'weights')

VAE = VAEModel(encoder, decoder)
VAE.compile(optimizer=keras.optimizers.Adam(lr=LEARNING_RATE))
# Out:
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/optimizer_v2/optimizer_v2.py:375: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   "The `lr` argument is deprecated, use `learning_rate` instead.")

# %%
MODE = 'build'
#MODE = 'load'

if MODE == 'load':
    #ae = keras.models.load_model(save_folder, custom_objects={'r_loss': r_loss})
    VAE.load_weights(save_folder+'/'+'checkpoint')

# %% [markdown]
# **Train**

# %%
def step_decay_schedule(initial_lr, decay_factor=0.5, step_size=1):
    '''
    Wrapper function to create a LearningRateScheduler with step decay schedule.
    '''
    def schedule(epoch):
        new_lr = initial_lr * (decay_factor ** np.floor(epoch/step_size))
        return new_lr

    return LearningRateScheduler(schedule)

checkpoint = ModelCheckpoint(save_folder+'/'+'checkpoint', save_weights_only = False, verbose=1)
lr_sched = step_decay_schedule(initial_lr=LEARNING_RATE, decay_factor=1, step_size=1)
callbacks_list = [checkpoint, lr_sched]

VAE.fit(
    data_flow,
    shuffle=True,
    epochs=EPOCHS,
    steps_per_epoch = NUM_IMAGES / BATCH_SIZE,
    callbacks=callbacks_list
)
# Out:
# Epoch 1/200
# 6175/6331 [============================>.] - ETA: 5s - loss: 5210.8567 - reconstruction_loss: 5095.7550 - kl_loss: 115.1017
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-20-369ebb0eb139> in <module>()
#      18     epochs=EPOCHS,
#      19     steps_per_epoch = NUM_IMAGES / BATCH_SIZE,
# ---> 20     callbacks=callbacks_list
#      21 )
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1181                 _r=1):
#    1182               callbacks.on_train_batch_begin(step)
# -> 1183               tmp_logs = self.train_function(iterator)
#    1184               if data_handler.should_sync:
#    1185                 context.async_wait()
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/def_function.py in __call__(self, *args, **kwds)
#     887
#     888       with OptionalXlaContext(self._jit_compile):
# --> 889         result = self._call(*args, **kwds)
#     890
#     891       new_tracing_count = self.experimental_get_tracing_count()
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/def_function.py in _call(self, *args, **kwds)
#     915       # In this case we have created variables on the first call, so we run the
#     916       # defunned version which is guaranteed to never create variables.
# --> 917       return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     918     elif self._stateful_fn is not None:
#     919       # Release the lock early so that multiple threads can perform the call
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/function.py in __call__(self, *args, **kwargs)
#    3022        filtered_flat_args) = self._maybe_define_function(args, kwargs)
#    3023     return graph_function._call_flat(
# -> 3024         filtered_flat_args, captured_inputs=graph_function.captured_inputs)  # pylint: disable=protected-access
#    3025
#    3026   @property
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1959       # No tape is watching; skip to running the function.
#    1960       return self._build_call_outputs(self._inference_function.call(
# -> 1961           ctx, args, cancellation_manager=cancellation_manager))
#    1962     forward_backward = self._select_forward_and_backward_functions(
#    1963         args,
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/function.py in call(self, ctx, args, cancellation_manager)
#     594               inputs=args,
#     595               attrs=attrs,
# --> 596               ctx=ctx)
#     597         else:
#     598           outputs = execute.execute_with_cancellation(
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      58     ctx.ensure_initialized()
#      59     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
# ---> 60                                         inputs, attrs, num_outputs)
#      61   except core._NotOkStatusException as e:
#      62     if name is not None:
#
# KeyboardInterrupt:

# %% [markdown]
# 학습이 완료된 모델 weights 저장

# %%
x = np.random.rand(1, 128, 128, 3)
VAE.predict(x)
VAE.save(save_folder)

# %%
# !mkdir -p /mydrive/vae
# !cp -r vae_data/weights /mydrive/vae

# !mkdir -p vae
# !cp -r vae_data/weights vae

# %% [markdown]
# 미리 학습된 weights 다운로드

# %%
#md5 = 'f503e59c23309a6f3f6348befc0ecde0'  
#url = 'https://drive.google.com/uc?id=15C6ad4coHKqbh5mtPGwreub5pX_Mnw-f'
#output = 'vae_weights2.tar.gz'

md5 = 'b387a8f59bd8bc09ee1eb12a80294379'  
url = 'https://drive.google.com/uc?id=19m6cQVNqXRhD6iEGkjA8ZZcOdev_b2V1'
output = 'vae_weights.tar.gz'

gdown.cached_download(url, output, md5=md5)
# Out:
# Cached Downloading: vae_weights.tar.gz
# Downloading...
# From: https://drive.google.com/uc?id=19m6cQVNqXRhD6iEGkjA8ZZcOdev_b2V1
# To: /root/.cache/gdown/tmpmnz52udz/dl
# 59.2MB [00:00, 74.9MB/s]
# Computing MD5: vae_weights.tar.gz
# MD5 matches: vae_weights.tar.gz
# 'vae_weights.tar.gz'

# %% [markdown]
# weights 압축 해제

# %%
# !tar xvzf vae_weights.tar.gz -C vae_data
# Out:
# weights/
# weights/keras_metadata.pb
# weights/checkpoint.data-00000-of-00001
# weights/checkpoint.index
# weights/variables/
# weights/variables/variables.data-00000-of-00001
# weights/variables/variables.index
# weights/saved_model.pb
# weights/checkpoint
# weights/assets/

# %% [markdown]
# weights 로드

# %%
VAE.load_weights(save_folder+'/'+'checkpoint')

# %% [markdown]
# ## VAE 분석

# %%
import numpy as np
import matplotlib.pyplot as plt
import numpy as np
import os
from scipy.stats import norm
import pandas as pd

vae = VAE

# %%
DATA_FOLDER = './vae_data/celeb/'
IMAGE_FOLDER = './vae_data/celeb/img_align_celeba/'

# %%
class ImageLabelLoader():
    def __init__(self, image_folder, target_size):
        self.image_folder = image_folder
        self.target_size = target_size

    def build(self, att, batch_size, label = None):

        data_gen = ImageDataGenerator(rescale=1./255)
        if label:
            data_flow = data_gen.flow_from_dataframe(
                att
                , self.image_folder
                , x_col='image_id'
                , y_col=label
                , target_size=self.target_size
                , class_mode='raw'
                , batch_size=batch_size
                , shuffle=True
            )
        else:
            data_flow = data_gen.flow_from_dataframe(
                att
                , self.image_folder
                , x_col='image_id'
                , target_size=self.target_size
                , class_mode='input'
                , batch_size=batch_size
                , shuffle=True
            )

        return data_flow

# %%
INPUT_DIM = (128,128,3)

att = pd.read_csv(os.path.join(DATA_FOLDER, 'list_attr_celeba.csv'))

imageLoader = ImageLabelLoader(IMAGE_FOLDER, INPUT_DIM[:2])

# %%
att.head()
# Out:
#      image_id  5_o_Clock_Shadow  ...  Wearing_Necktie  Young
# 0  000001.jpg                -1  ...               -1      1
# 1  000002.jpg                -1  ...               -1      1
# 2  000003.jpg                -1  ...               -1      1
# 3  000004.jpg                -1  ...               -1      1
# 4  000005.jpg                -1  ...               -1      1
#
# [5 rows x 41 columns]

# %% [markdown]
# **이미지 복원**

# %%
n_to_show = 10

data_flow_generic = imageLoader.build(att, n_to_show)

example_batch = next(data_flow_generic)
example_images = example_batch[0]

_,_,z_points = vae.encoder.predict(example_images)

reconst_images = vae.decoder.predict(z_points)

fig = plt.figure(figsize=(15, 3))
fig.subplots_adjust(hspace=0.4, wspace=0.4)

for i in range(n_to_show):
    img = example_images[i].squeeze()
    sub = fig.add_subplot(2, n_to_show, i+1)
    sub.axis('off')        
    sub.imshow(img)

for i in range(n_to_show):
    img = reconst_images[i].squeeze()
    sub = fig.add_subplot(2, n_to_show, i+n_to_show+1)
    sub.axis('off')
    sub.imshow(img)
# Out:
# Found 202599 validated image filenames.

# %% [markdown]
# **새로 얼굴 생성하기**

# %%
z_dim = 200
n_to_show = 30

znew = np.random.normal(size = (n_to_show,z_dim))/1

reconst = vae.decoder.predict(np.array(znew))

fig = plt.figure(figsize=(18, 5))
fig.subplots_adjust(hspace=0.4, wspace=0.4)
for i in range(n_to_show):
    ax = fig.add_subplot(3, 10, i+1)
    ax.imshow(reconst[i, :,:,:])
    ax.axis('off')

plt.show()

# %%
def get_vector_from_label(label, batch_size):

    data_flow_label = imageLoader.build(att, batch_size, label = label)

    origin = np.zeros(shape = z_dim, dtype = 'float32')
    current_sum_POS = np.zeros(shape = z_dim, dtype = 'float32')
    current_n_POS = 0
    current_mean_POS = np.zeros(shape = z_dim, dtype = 'float32')

    current_sum_NEG = np.zeros(shape = z_dim, dtype = 'float32')
    current_n_NEG = 0
    current_mean_NEG = np.zeros(shape = z_dim, dtype = 'float32')

    current_vector = np.zeros(shape = z_dim, dtype = 'float32')
    current_dist = 0

    print('label: ' + label)
    print('images : POS move : NEG move :distance : 𝛥 distance')
    while(current_n_POS < 10000):

        batch = next(data_flow_label)
        im = batch[0]
        attribute = batch[1]

        _,_,z = vae.encoder.predict(np.array(im))

        z_POS = z[attribute==1]
        z_NEG = z[attribute==-1]

        if len(z_POS) > 0:
            current_sum_POS = current_sum_POS + np.sum(z_POS, axis = 0)
            current_n_POS += len(z_POS)
            new_mean_POS = current_sum_POS / current_n_POS
            movement_POS = np.linalg.norm(new_mean_POS-current_mean_POS)

        if len(z_NEG) > 0: 
            current_sum_NEG = current_sum_NEG + np.sum(z_NEG, axis = 0)
            current_n_NEG += len(z_NEG)
            new_mean_NEG = current_sum_NEG / current_n_NEG
            movement_NEG = np.linalg.norm(new_mean_NEG-current_mean_NEG)

        current_vector = new_mean_POS-new_mean_NEG
        new_dist = np.linalg.norm(current_vector)
        dist_change = new_dist - current_dist


        print(str(current_n_POS)
              + '    : ' + str(np.round(movement_POS,3))
              + '    : ' + str(np.round(movement_NEG,3))
              + '    : ' + str(np.round(new_dist,3))
              + '    : ' + str(np.round(dist_change,3))
             )

        current_mean_POS = np.copy(new_mean_POS)
        current_mean_NEG = np.copy(new_mean_NEG)
        current_dist = np.copy(new_dist)

        if np.sum([movement_POS, movement_NEG]) < 0.08:
            current_vector = current_vector / current_dist
            print('Found the ' + label + ' vector')
            break

    return current_vector

# %%
def add_vector_to_images(feature_vec):

    n_to_show = 5
    factors = [-4,-3,-2,-1,0,1,2,3,4]

    example_batch = next(data_flow_generic)
    example_images = example_batch[0]
    example_labels = example_batch[1]

    _,_,z_points = vae.encoder.predict(example_images)

    fig = plt.figure(figsize=(18, 10))

    counter = 1

    for i in range(n_to_show):

        img = example_images[i].squeeze()
        sub = fig.add_subplot(n_to_show, len(factors) + 1, counter)
        sub.axis('off')        
        sub.imshow(img)

        counter += 1

        for factor in factors:

            changed_z_point = z_points[i] + feature_vec * factor
            changed_image = vae.decoder.predict(np.array([changed_z_point]))[0]

            img = changed_image.squeeze()
            sub = fig.add_subplot(n_to_show, len(factors) + 1, counter)
            sub.axis('off')
            sub.imshow(img)

            counter += 1

    plt.show()

# %%
BATCH_SIZE = 500

# %%
# attractive_vec = get_vector_from_label('Attractive', BATCH_SIZE)
# mouth_open_vec = get_vector_from_label('Mouth_Slightly_Open', BATCH_SIZE)
# smiling_vec = get_vector_from_label('Smiling', BATCH_SIZE)
# lipstick_vec = get_vector_from_label('Wearing_Lipstick', BATCH_SIZE)
# young_vec = get_vector_from_label('High_Cheekbones', BATCH_SIZE)
# male_vec = get_vector_from_label('Male', BATCH_SIZE)
eyeglasses_vec = get_vector_from_label('Eyeglasses', BATCH_SIZE)
# blonde_vec = get_vector_from_label('Blond_Hair', BATCH_SIZE)
# Out:
# Found 202599 validated image filenames.
# label: Eyeglasses
# images : POS move : NEG move :distance : 𝛥 distance
# 35    : 3.161    : 0.764    : 3.3    : 3.3
# 62    : 1.512    : 0.434    : 2.752    : -0.548
# 92    : 1.059    : 0.269    : 2.479    : -0.273
# 116    : 0.705    : 0.182    : 2.459    : -0.021
# 143    : 0.566    : 0.139    : 2.401    : -0.057
# 170    : 0.442    : 0.127    : 2.277    : -0.124
# 201    : 0.444    : 0.099    : 2.237    : -0.041
# 228    : 0.348    : 0.089    : 2.201    : -0.036
# 258    : 0.349    : 0.074    : 2.19    : -0.011
# 292    : 0.333    : 0.07    : 2.168    : -0.021
# 321    : 0.284    : 0.062    : 2.149    : -0.02
# 361    : 0.276    : 0.056    : 2.163    : 0.015
# 395    : 0.206    : 0.05    : 2.154    : -0.01
# 430    : 0.21    : 0.047    : 2.162    : 0.008
# 465    : 0.178    : 0.039    : 2.144    : -0.018
# 504    : 0.2    : 0.043    : 2.115    : -0.029
# 537    : 0.167    : 0.04    : 2.118    : 0.002
# 574    : 0.148    : 0.036    : 2.084    : -0.033
# 603    : 0.134    : 0.034    : 2.061    : -0.023
# 642    : 0.155    : 0.032    : 2.079    : 0.018
# 684    : 0.137    : 0.031    : 2.07    : -0.009
# 722    : 0.133    : 0.032    : 2.054    : -0.016
# 745    : 0.088    : 0.028    : 2.058    : 0.004
# 775    : 0.103    : 0.028    : 2.048    : -0.01
# 804    : 0.098    : 0.027    : 2.052    : 0.004
# 843    : 0.117    : 0.027    : 2.035    : -0.016
# 887    : 0.105    : 0.023    : 2.015    : -0.021
# 923    : 0.094    : 0.023    : 2.004    : -0.011
# 955    : 0.081    : 0.023    : 1.995    : -0.009
# 993    : 0.092    : 0.024    : 1.987    : -0.007
# 1033    : 0.091    : 0.022    : 1.982    : -0.006
# 1070    : 0.092    : 0.021    : 1.98    : -0.002
# 1104    : 0.084    : 0.021    : 1.979    : -0.001
# 1136    : 0.075    : 0.021    : 1.979    : -0.0
# 1158    : 0.06    : 0.019    : 1.984    : 0.005
# Found the Eyeglasses vector

# %%
# print('Attractive Vector')
# add_vector_to_images(attractive_vec)

# print('Mouth Open Vector')
# add_vector_to_images(mouth_open_vec)

# print('Smiling Vector')
# add_vector_to_images(smiling_vec)

# print('Lipstick Vector')
# add_vector_to_images(lipstick_vec)

# print('Young Vector')
# add_vector_to_images(young_vec)

# print('Male Vector')
# add_vector_to_images(male_vec)

print('Eyeglasses Vector')
add_vector_to_images(eyeglasses_vec)

# print('Blond Vector')
# add_vector_to_images(blonde_vec)
# Out:
# Eyeglasses Vector

# %%
def morph_faces(start_image_file, end_image_file):

    factors = np.arange(0,1,0.1)

    att_specific = att[att['image_id'].isin([start_image_file, end_image_file])]
    att_specific = att_specific.reset_index()
    data_flow_label = imageLoader.build(att_specific, 2)

    example_batch = next(data_flow_label)
    example_images = example_batch[0]
    example_labels = example_batch[1]

    _,_,z_points = vae.encoder.predict(example_images)


    fig = plt.figure(figsize=(18, 8))

    counter = 1

    img = example_images[0].squeeze()
    sub = fig.add_subplot(1, len(factors)+2, counter)
    sub.axis('off')        
    sub.imshow(img)

    counter+=1


    for factor in factors:

        changed_z_point = z_points[0] * (1-factor) + z_points[1]  * factor
        changed_image = vae.decoder.predict(np.array([changed_z_point]))[0]

        img = changed_image.squeeze()
        sub = fig.add_subplot(1, len(factors)+2, counter)
        sub.axis('off')
        sub.imshow(img)

        counter += 1

    img = example_images[1].squeeze()
    sub = fig.add_subplot(1, len(factors)+2, counter)
    sub.axis('off')        
    sub.imshow(img)


    plt.show()

# %%
start_image_file = '000238.jpg' 
end_image_file = '000193.jpg' #glasses

morph_faces(start_image_file, end_image_file)
# Out:
# Found 2 validated image filenames.

# %%
start_image_file = '000112.jpg'
end_image_file = '000258.jpg'

morph_faces(start_image_file, end_image_file)
# Out:
# Found 2 validated image filenames.

# %%
start_image_file = '000230.jpg'
end_image_file = '000712.jpg'

morph_faces(start_image_file, end_image_file)
# Out:
# Found 2 validated image filenames.

# %% [markdown]
# # Face swapping

# %% [markdown]
# Original source code from:
# https://github.com/EXJUSTICE/DeepFake_FaceSwap

# %%
# !git clone -b tensorflow2.update --single-branch https://github.com/shevious/DeepFake_FaceSwap.git --depth=1
# Out:
# Cloning into 'DeepFake_FaceSwap'...
# remote: Enumerating objects: 449, done.
# remote: Counting objects: 100% (449/449), done.
# remote: Compressing objects: 100% (446/446), done.
# remote: Total 449 (delta 4), reused 443 (delta 3), pack-reused 0
# Receiving objects: 100% (449/449), 11.86 MiB | 5.34 MiB/s, done.
# Resolving deltas: 100% (4/4), done.

# %%
# %cd DeepFake_FaceSwap
# Out:
# /content/DeepFake_FaceSwap

# %%
# !mkdir -p obama-cut
# !mkdir -p clinton-cut
# !mkdir -p saved_model
# !mkdir -p test

# %%
pip install cmake
# Out:
# Requirement already satisfied: cmake in /usr/local/lib/python3.7/dist-packages (3.12.0)

# %%
pip install face_recognition
# Out:
# Collecting face_recognition
#   Downloading https://files.pythonhosted.org/packages/1e/95/f6c9330f54ab07bfa032bf3715c12455a381083125d8880c43cbe76bb3d0/face_recognition-1.3.0-py2.py3-none-any.whl
# Requirement already satisfied: Pillow in /usr/local/lib/python3.7/dist-packages (from face_recognition) (7.1.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from face_recognition) (1.19.5)
# Requirement already satisfied: dlib>=19.7 in /usr/local/lib/python3.7/dist-packages (from face_recognition) (19.18.0)
# Requirement already satisfied: Click>=6.0 in /usr/local/lib/python3.7/dist-packages (from face_recognition) (7.1.2)
# Collecting face-recognition-models>=0.3.0
#   Downloading https://files.pythonhosted.org/packages/cf/3b/4fd8c534f6c0d1b80ce0973d01331525538045084c73c153ee6df20224cf/face_recognition_models-0.3.0.tar.gz (100.1MB)
#      |████████████████████████████████| 100.2MB 59kB/s
# Building wheels for collected packages: face-recognition-models
#   Building wheel for face-recognition-models (setup.py) ... done
#   Created wheel for face-recognition-models: filename=face_recognition_models-0.3.0-py2.py3-none-any.whl size=100566184 sha256=26ee850a5480a80d759ce73510c1ade569fc9a3e5043708c9762772d2b9f3724
#   Stored in directory: /root/.cache/pip/wheels/d2/99/18/59c6c8f01e39810415c0e63f5bede7d83dfb0ffc039865465f
# Successfully built face-recognition-models
# Installing collected packages: face-recognition-models, face-recognition
# Successfully installed face-recognition-1.3.0 face-recognition-models-0.3.0

# %%
pip install scandir
# Out:
# Collecting scandir
#   Downloading https://files.pythonhosted.org/packages/df/f5/9c052db7bd54d0cbf1bc0bb6554362bba1012d03e5888950a4f5c5dadc4e/scandir-1.10.0.tar.gz
# Building wheels for collected packages: scandir
#   Building wheel for scandir (setup.py) ... done
#   Created wheel for scandir: filename=scandir-1.10.0-cp37-cp37m-linux_x86_64.whl size=40757 sha256=303c03991091414acaf105f787dce7d3ba6512c660321640e7c88c3e1d028083
#   Stored in directory: /root/.cache/pip/wheels/91/95/75/19c98a91239878abbc7c59970abd3b4e0438a7dd5b61778335
# Successfully built scandir
# Installing collected packages: scandir
# Successfully installed scandir-1.10.0

# %%
pip install opencv-python
# Out:
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.7/dist-packages (4.1.2.30)
# Requirement already satisfied: numpy>=1.14.5 in /usr/local/lib/python3.7/dist-packages (from opencv-python) (1.19.5)

# %%
import cv2
from pathlib import Path
import face_recognition
from lib_1.PluginLoader import PluginLoader
from lib_1.faces_detect import detect_faces
from lib_1.FaceFilter import FaceFilter
import os

# %%
input_directory="obama-jpg"
output_directory="obama-cut"
filter_file = 'filter/obamafilter.jpg'

# %%
def load_filter():
    #filter_file = '../content/filter/obamafilter.jpg' # TODO Change argument here depending on what youre trying to extract
    if os.path.exists(filter_file):
        print('Loading reference image for filtering')
        return FaceFilter(filter_file)
    else:
        print("Filter not detected")

def get_faces(image):
    faces_count = 0
    filterDeepFake = load_filter()

    for face in detect_faces(image):

        if filterDeepFake is not None and not filterDeepFake.check(face):
            print('Skipping not recognized face!')
            continue


        yield faces_count, face

# %%
from matplotlib import pyplot as plt
# from google.colab.patches import cv2_imshow

extractor_name = "Align" # TODO Pass as argument
extractor = PluginLoader.get_extractor(extractor_name)()
# Out:
# Loading Extract from Extract_Align plugin...

# %% [markdown]
# **얼굴 이미지 추출**

# %%
"""

#Single Example test

example  ="../content/data/CR_2012.jpg"


image = cv2.imread(example)

for idx, face in get_faces(image):
           resized_image = extractor.extract(image, face, 256)
           output_file = output_directory+"/"+str(Path(example).stem)
           cv2.imwrite(str(output_file) + str(idx) + Path(example).suffix, resized_image)
"""
#Simply iterating over the folder is insufficient, imread needs paths, so create them into a list.


def find_all_files(directory):
    for root, dirs, files in os.walk(directory):

        for file in files:
            p=os.path.join(root, file)
            p=p.split("/")[len(p.split("/"))-2]
            name, ext = os.path.splitext(p)

            yield os.path.join(root, file)

folder_img = find_all_files(input_directory)
try:
    for filename in folder_img:
        image = cv2.imread(filename)
        print(filename)
        for idx, face in get_faces(image):
            print('extractor')
            resized_image = extractor.extract(image, face, 256)
            output_file = output_directory+"/"+str(Path(filename).stem)
            print('imwrite')
            cv2.imwrite(str(output_file) + str(idx) + Path(filename).suffix, resized_image)

except Exception as e:
    print('Failed to extract from image: {}. Reason: {}'.format(filename, e))

input_directory="clinton-jpg"
output_directory="clinton-cut"
filter_file = 'filter/clintonfilter.jpg'

folder_img = find_all_files(input_directory)
try:
    for filename in folder_img:
        image = cv2.imread(filename)
        print(filename)
        for idx, face in get_faces(image):
            print('extractor')
            resized_image = extractor.extract(image, face, 256)
            output_file = output_directory+"/"+str(Path(filename).stem)
            print('imwrite')
            cv2.imwrite(str(output_file) + str(idx) + Path(filename).suffix, resized_image)

except Exception as e:
    print('Failed to extract from image: {}. Reason: {}'.format(filename, e))
# Out:
# obama-jpg/164.jpg
# Loading reference image for filtering
# -----
# check
# [0.33928473]
# extractor
# imwrite
# obama-jpg/043.jpg
# Loading reference image for filtering
# -----
# check
# [0.34081013]
# extractor
# imwrite
# obama-jpg/030.jpg
# Loading reference image for filtering
# -----
# check
# [0.40629661]
# extractor
# imwrite
# obama-jpg/091.jpg
# Loading reference image for filtering
# -----
# check
# [0.43430513]
# extractor
# imwrite
# obama-jpg/006.jpg
# Loading reference image for filtering
# -----
# check
# [0.34260841]
# extractor
# imwrite
# check
# No faces found in the image!
# 0.8
# Skipping not recognized face!
# obama-jpg/102.jpg
# Loading reference image for filtering
# -----
# check
# [0.28352454]
# extractor
# imwrite
# obama-jpg/167.jpg
# Loading reference image for filtering
# -----
# check
# [0.28692467]
# extractor
# imwrite
# obama-jpg/172.jpg
# Loading reference image for filtering
# -----
# check
# [0.36425869]
# extractor
# imwrite
# obama-jpg/122.jpg
# Loading reference image for filtering
# -----
# check
# [0.32092847]
# extractor
# imwrite
# obama-jpg/130.jpg
# Loading reference image for filtering
# -----
# check
# [0.44813999]
# extractor
# imwrite
# obama-jpg/092.jpg
# Loading reference image for filtering
# -----
# check
# [0.46187501]
# extractor
# imwrite
# obama-jpg/053.jpg
# Loading reference image for filtering
# -----
# check
# [0.43182306]
# extractor
# imwrite
# obama-jpg/099.jpg
# Loading reference image for filtering
# -----
# check
# [0.43965444]
# extractor
# imwrite
# obama-jpg/032.jpg
# Loading reference image for filtering
# -----
# check
# [0.3346673]
# extractor
# imwrite
# obama-jpg/117.jpg
# Loading reference image for filtering
# -----
# check
# [0.33437308]
# extractor
# imwrite
# obama-jpg/178.jpg
# Loading reference image for filtering
# -----
# check
# [0.3951766]
# extractor
# imwrite
# obama-jpg/152.jpg
# Loading reference image for filtering
# -----
# check
# [0.31476338]
# extractor
# imwrite
# obama-jpg/101.jpg
# Loading reference image for filtering
# -----
# check
# [0.3667221]
# extractor
# imwrite
# obama-jpg/115.jpg
# Loading reference image for filtering
# -----
# check
# [0.33250114]
# extractor
# imwrite
# obama-jpg/074.jpg
# Loading reference image for filtering
# -----
# check
# [0.31186839]
# extractor
# imwrite
# obama-jpg/168.jpg
# Loading reference image for filtering
# -----
# check
# [0.2640026]
# extractor
# imwrite
# obama-jpg/177.jpg
# Loading reference image for filtering
# -----
# check
# [0.32652369]
# extractor
# imwrite
# obama-jpg/066.jpg
# Loading reference image for filtering
# -----
# check
# [0.35863725]
# extractor
# imwrite
# obama-jpg/136.jpg
# Loading reference image for filtering
# -----
# check
# [0.43818624]
# extractor
# imwrite
# obama-jpg/087.jpg
# Loading reference image for filtering
# -----
# check
# [0.33609116]
# extractor
# imwrite
# obama-jpg/161.jpg
# Loading reference image for filtering
# -----
# check
# [0.44650195]
# extractor
# imwrite
# obama-jpg/153.jpg
# Loading reference image for filtering
# -----
# check
# [0.31440063]
# extractor
# imwrite
# obama-jpg/104.jpg
# Loading reference image for filtering
# -----
# check
# [0.37749854]
# extractor
# imwrite
# obama-jpg/007.jpg
# Loading reference image for filtering
# -----
# check
# [0.33859351]
# extractor
# imwrite
# obama-jpg/042.jpg
# Loading reference image for filtering
# -----
# check
# [0.34142451]
# extractor
# imwrite
# obama-jpg/036.jpg
# Loading reference image for filtering
# -----
# check
# [0.3704478]
# extractor
# imwrite
# obama-jpg/120.jpg
# Loading reference image for filtering
# -----
# check
# [0.35302044]
# extractor
# imwrite
# obama-jpg/076.jpg
# Loading reference image for filtering
# -----
# check
# [0.36922735]
# extractor
# imwrite
# obama-jpg/055.jpg
# Loading reference image for filtering
# -----
# check
# [0.34890496]
# extractor
# imwrite
# obama-jpg/052.jpg
# Loading reference image for filtering
# -----
# check
# [0.35657308]
# extractor
# imwrite
# obama-jpg/014.jpg
# Loading reference image for filtering
# -----
# check
# [0.3024926]
# extractor
# imwrite
# obama-jpg/173.jpg
# Loading reference image for filtering
# -----
# check
# [0.36062628]
# extractor
# imwrite
# obama-jpg/111.jpg
# Loading reference image for filtering
# -----
# check
# [0.28788814]
# extractor
# imwrite
# obama-jpg/121.jpg
# Loading reference image for filtering
# -----
# check
# [0.36255254]
# extractor
# imwrite
# obama-jpg/113.jpg
# Loading reference image for filtering
# -----
# check
# [0.34265854]
# extractor
# imwrite
# obama-jpg/027.jpg
# Loading reference image for filtering
# -----
# check
# [0.33707859]
# extractor
# imwrite
# obama-jpg/072.jpg
# Loading reference image for filtering
# -----
# check
# [0.27900907]
# extractor
# imwrite
# obama-jpg/157.jpg
# Loading reference image for filtering
# -----
# check
# [0.31286163]
# extractor
# imwrite
# obama-jpg/107.jpg
# Loading reference image for filtering
# -----
# check
# [0.39787094]
# extractor
# imwrite
# obama-jpg/096.jpg
# Loading reference image for filtering
# -----
# check
# [0.45682486]
# extractor
# imwrite
# obama-jpg/080.jpg
# Loading reference image for filtering
# -----
# check
# [0.34705771]
# extractor
# imwrite
# obama-jpg/023.jpg
# Loading reference image for filtering
# -----
# check
# [0.3598728]
# extractor
# imwrite
# obama-jpg/013.jpg
# Loading reference image for filtering
# -----
# check
# [0.34679956]
# extractor
# imwrite
# obama-jpg/068.jpg
# Loading reference image for filtering
# -----
# check
# [0.29568001]
# extractor
# imwrite
# obama-jpg/046.jpg
# Loading reference image for filtering
# -----
# check
# [0.33062883]
# extractor
# imwrite
# obama-jpg/059.jpg
# Loading reference image for filtering
# -----
# check
# [0.36133285]
# extractor
# imwrite
# obama-jpg/025.jpg
# Loading reference image for filtering
# -----
# check
# [0.42875086]
# extractor
# imwrite
# obama-jpg/097.jpg
# Loading reference image for filtering
# -----
# check
# [0.41021652]
# extractor
# imwrite
# obama-jpg/017.jpg
# Loading reference image for filtering
# -----
# check
# [0.29762758]
# extractor
# imwrite
# obama-jpg/109.jpg
# Loading reference image for filtering
# -----
# check
# [0.30093193]
# extractor
# imwrite
# obama-jpg/154.jpg
# Loading reference image for filtering
# -----
# check
# [0.31645777]
# extractor
# imwrite
# obama-jpg/171.jpg
# Loading reference image for filtering
# -----
# check
# [0.27257184]
# extractor
# imwrite
# obama-jpg/182.jpg
# Loading reference image for filtering
# -----
# check
# [0.35582085]
# extractor
# imwrite
# obama-jpg/067.jpg
# Loading reference image for filtering
# -----
# check
# [0.33072535]
# extractor
# imwrite
# obama-jpg/125.jpg
# Loading reference image for filtering
# -----
# check
# [0.31718983]
# extractor
# imwrite
# obama-jpg/142.jpg
# Loading reference image for filtering
# -----
# check
# [0.47269453]
# extractor
# imwrite
# obama-jpg/061.jpg
# Loading reference image for filtering
# -----
# check
# [0.34035095]
# extractor
# imwrite
# obama-jpg/033.jpg
# Loading reference image for filtering
# -----
# check
# [0.32958142]
# extractor
# imwrite
# obama-jpg/034.jpg
# Loading reference image for filtering
# -----
# check
# [0.37343169]
# extractor
# imwrite
# obama-jpg/179.jpg
# Loading reference image for filtering
# -----
# check
# [0.42705668]
# extractor
# imwrite
# obama-jpg/144.jpg
# Loading reference image for filtering
# -----
# check
# [0.44209319]
# extractor
# imwrite
# obama-jpg/044.jpg
# Loading reference image for filtering
# -----
# check
# [0.34435204]
# extractor
# imwrite
# obama-jpg/159.jpg
# Loading reference image for filtering
# -----
# check
# [0.35292301]
# extractor
# imwrite
# obama-jpg/021.jpg
# Loading reference image for filtering
# -----
# check
# [0.37543421]
# extractor
# imwrite
# obama-jpg/015.jpg
# Loading reference image for filtering
# -----
# check
# [0.31433068]
# extractor
# imwrite
# obama-jpg/123.jpg
# Loading reference image for filtering
# -----
# check
# [0.35228117]
# extractor
# imwrite
# obama-jpg/077.jpg
# Loading reference image for filtering
# -----
# check
# [0.38790644]
# extractor
# imwrite
# obama-jpg/105.jpg
# Loading reference image for filtering
# -----
# check
# [0.33708514]
# extractor
# imwrite
# obama-jpg/041.jpg
# Loading reference image for filtering
# -----
# check
# [0.34583608]
# extractor
# imwrite
# obama-jpg/071.jpg
# Loading reference image for filtering
# -----
# check
# [0.29077798]
# extractor
# imwrite
# obama-jpg/116.jpg
# Loading reference image for filtering
# -----
# check
# [0.3631614]
# extractor
# imwrite
# obama-jpg/148.jpg
# Loading reference image for filtering
# -----
# check
# [0.30994336]
# extractor
# imwrite
# obama-jpg/018.jpg
# Loading reference image for filtering
# -----
# check
# [0.30527454]
# extractor
# imwrite
# obama-jpg/090.jpg
# Loading reference image for filtering
# -----
# check
# [0.4211529]
# extractor
# imwrite
# obama-jpg/093.jpg
# Loading reference image for filtering
# -----
# check
# [0.4715486]
# extractor
# imwrite
# obama-jpg/094.jpg
# Loading reference image for filtering
# -----
# check
# [0.45532972]
# extractor
# imwrite
# obama-jpg/139.jpg
# Loading reference image for filtering
# -----
# check
# [0.43990897]
# extractor
# imwrite
# obama-jpg/098.jpg
# Loading reference image for filtering
# -----
# check
# [0.44858929]
# extractor
# imwrite
# obama-jpg/069.jpg
# Loading reference image for filtering
# -----
# check
# [0.30624673]
# extractor
# imwrite
# obama-jpg/022.jpg
# Loading reference image for filtering
# -----
# check
# [0.33679105]
# extractor
# imwrite
# obama-jpg/140.jpg
# Loading reference image for filtering
# -----
# check
# [0.45159293]
# extractor
# imwrite
# obama-jpg/085.jpg
# Loading reference image for filtering
# -----
# check
# [0.32114036]
# extractor
# imwrite
# obama-jpg/073.jpg
# Loading reference image for filtering
# -----
# check
# [0.38599088]
# extractor
# imwrite
# obama-jpg/040.jpg
# Loading reference image for filtering
# -----
# check
# [0.34180992]
# extractor
# imwrite
# obama-jpg/028.jpg
# Loading reference image for filtering
# -----
# check
# [0.30199097]
# extractor
# imwrite
# obama-jpg/002.jpg
# Loading reference image for filtering
# -----
# check
# [0.25030985]
# extractor
# imwrite
# obama-jpg/143.jpg
# Loading reference image for filtering
# -----
# check
# [0.44504155]
# extractor
# imwrite
# obama-jpg/008.jpg
# Loading reference image for filtering
# -----
# check
# [0.31233655]
# extractor
# imwrite
# obama-jpg/019.jpg
# Loading reference image for filtering
# -----
# check
# [0.31627142]
# extractor
# imwrite
# obama-jpg/158.jpg
# Loading reference image for filtering
# -----
# check
# [0.34181663]
# extractor
# imwrite
# obama-jpg/165.jpg
# Loading reference image for filtering
# -----
# check
# [0.36044874]
# extractor
# imwrite
# obama-jpg/083.jpg
# Loading reference image for filtering
# -----
# check
# [0.33430596]
# extractor
# imwrite
# obama-jpg/166.jpg
# Loading reference image for filtering
# -----
# check
# [0.28215301]
# extractor
# imwrite
# obama-jpg/010.jpg
# Loading reference image for filtering
# -----
# check
# [0.36444933]
# extractor
# imwrite
# obama-jpg/062.jpg
# Loading reference image for filtering
# -----
# check
# [0.33302911]
# extractor
# imwrite
# obama-jpg/078.jpg
# Loading reference image for filtering
# -----
# check
# [0.31875002]
# extractor
# imwrite
# obama-jpg/005.jpg
# Loading reference image for filtering
# -----
# check
# [0.41041022]
# extractor
# imwrite
# obama-jpg/016.jpg
# Loading reference image for filtering
# -----
# check
# [0.27396131]
# extractor
# imwrite
# obama-jpg/084.jpg
# Loading reference image for filtering
# -----
# check
# [0.33187489]
# extractor
# imwrite
# obama-jpg/060.jpg
# Loading reference image for filtering
# -----
# check
# [0.32304187]
# extractor
# imwrite
# obama-jpg/079.jpg
# Loading reference image for filtering
# -----
# check
# [0.33892514]
# extractor
# imwrite
# obama-jpg/086.jpg
# Loading reference image for filtering
# -----
# check
# [0.32129832]
# extractor
# imwrite
# obama-jpg/038.jpg
# Loading reference image for filtering
# -----
# check
# [0.31259622]
# extractor
# imwrite
# obama-jpg/001.jpg
# Loading reference image for filtering
# -----
# check
# [0.24638894]
# extractor
# imwrite
# obama-jpg/064.jpg
# Loading reference image for filtering
# -----
# check
# [0.38876138]
# extractor
# imwrite
# obama-jpg/054.jpg
# Loading reference image for filtering
# -----
# check
# [0.32963315]
# extractor
# imwrite
# obama-jpg/047.jpg
# Loading reference image for filtering
# -----
# check
# [0.33235353]
# extractor
# imwrite
# obama-jpg/132.jpg
# Loading reference image for filtering
# -----
# check
# [0.43143061]
# extractor
# imwrite
# obama-jpg/020.jpg
# Loading reference image for filtering
# -----
# check
# [0.37822047]
# extractor
# imwrite
# obama-jpg/175.jpg
# Loading reference image for filtering
# -----
# check
# [0.40544653]
# extractor
# imwrite
# obama-jpg/118.jpg
# Loading reference image for filtering
# -----
# check
# [0.41424875]
# extractor
# imwrite
# obama-jpg/134.jpg
# Loading reference image for filtering
# -----
# check
# [0.43306221]
# extractor
# imwrite
# obama-jpg/103.jpg
# Loading reference image for filtering
# -----
# check
# [0.36019492]
# extractor
# imwrite
# obama-jpg/106.jpg
# Loading reference image for filtering
# -----
# check
# [0.34706653]
# extractor
# imwrite
# obama-jpg/131.jpg
# Loading reference image for filtering
# -----
# check
# [0.41953036]
# extractor
# imwrite
# obama-jpg/045.jpg
# Loading reference image for filtering
# -----
# check
# [0.3407717]
# extractor
# imwrite
# obama-jpg/050.jpg
# Loading reference image for filtering
# -----
# check
# [0.33722277]
# extractor
# imwrite
# obama-jpg/024.jpg
# Loading reference image for filtering
# -----
# check
# [0.3167503]
# extractor
# imwrite
# obama-jpg/170.jpg
# Loading reference image for filtering
# -----
# check
# [0.30153754]
# extractor
# imwrite
# obama-jpg/156.jpg
# Loading reference image for filtering
# -----
# check
# [0.32883104]
# extractor
# imwrite
# obama-jpg/146.jpg
# Loading reference image for filtering
# -----
# check
# [0.40097914]
# extractor
# imwrite
# obama-jpg/145.jpg
# Loading reference image for filtering
# -----
# check
# [0.36952073]
# extractor
# imwrite
# obama-jpg/163.jpg
# Loading reference image for filtering
# -----
# check
# [0.41339651]
# extractor
# imwrite
# obama-jpg/169.jpg
# Loading reference image for filtering
# -----
# check
# [0.28922271]
# extractor
# imwrite
# obama-jpg/151.jpg
# Loading reference image for filtering
# -----
# check
# [0.31262676]
# extractor
# imwrite
# obama-jpg/181.jpg
# Loading reference image for filtering
# -----
# check
# [0.40920287]
# extractor
# imwrite
# obama-jpg/051.jpg
# Loading reference image for filtering
# -----
# check
# [0.3554101]
# extractor
# imwrite
# obama-jpg/009.jpg
# Loading reference image for filtering
# -----
# check
# [0.2685393]
# extractor
# imwrite
# obama-jpg/149.jpg
# Loading reference image for filtering
# -----
# check
# [0.34288443]
# extractor
# imwrite
# obama-jpg/065.jpg
# Loading reference image for filtering
# -----
# check
# [0.35374572]
# extractor
# imwrite
# obama-jpg/039.jpg
# Loading reference image for filtering
# -----
# check
# [0.40031409]
# extractor
# imwrite
# obama-jpg/004.jpg
# Loading reference image for filtering
# -----
# check
# [0.27273964]
# extractor
# imwrite
# obama-jpg/048.jpg
# Loading reference image for filtering
# -----
# check
# [0.35780801]
# extractor
# imwrite
# obama-jpg/160.jpg
# Loading reference image for filtering
# -----
# check
# [0.44182531]
# extractor
# imwrite
# obama-jpg/003.jpg
# Loading reference image for filtering
# -----
# check
# [0.25229311]
# extractor
# imwrite
# obama-jpg/082.jpg
# Loading reference image for filtering
# -----
# check
# [0.35768794]
# extractor
# imwrite
# obama-jpg/110.jpg
# Loading reference image for filtering
# -----
# check
# [0.28309671]
# extractor
# imwrite
# obama-jpg/119.jpg
# Loading reference image for filtering
# -----
# check
# [0.36031564]
# extractor
# imwrite
# obama-jpg/031.jpg
# Loading reference image for filtering
# -----
# check
# [0.36841089]
# extractor
# imwrite
# obama-jpg/124.jpg
# Loading reference image for filtering
# -----
# check
# [0.38924181]
# extractor
# imwrite
# obama-jpg/128.jpg
# Loading reference image for filtering
# -----
# check
# [0.32644686]
# extractor
# imwrite
# obama-jpg/135.jpg
# Loading reference image for filtering
# -----
# check
# [0.41960482]
# extractor
# imwrite
# obama-jpg/070.jpg
# Loading reference image for filtering
# -----
# check
# [0.31142333]
# extractor
# imwrite
# obama-jpg/108.jpg
# Loading reference image for filtering
# -----
# check
# [0.32782913]
# extractor
# imwrite
# obama-jpg/147.jpg
# Loading reference image for filtering
# -----
# check
# [0.35141438]
# extractor
# imwrite
# obama-jpg/127.jpg
# Loading reference image for filtering
# -----
# check
# [0.40952499]
# extractor
# imwrite
# obama-jpg/057.jpg
# Loading reference image for filtering
# -----
# check
# [0.35178748]
# extractor
# imwrite
# obama-jpg/133.jpg
# Loading reference image for filtering
# -----
# check
# [0.48027948]
# extractor
# imwrite
# obama-jpg/089.jpg
# Loading reference image for filtering
# -----
# check
# [0.44467925]
# extractor
# imwrite
# obama-jpg/150.jpg
# Loading reference image for filtering
# -----
# check
# [0.33473645]
# extractor
# imwrite
# obama-jpg/088.jpg
# Loading reference image for filtering
# -----
# check
# [0.3149858]
# extractor
# imwrite
# obama-jpg/141.jpg
# Loading reference image for filtering
# -----
# check
# [0.42077119]
# extractor
# imwrite
# obama-jpg/155.jpg
# Loading reference image for filtering
# -----
# check
# [0.30093084]
# extractor
# imwrite
# obama-jpg/029.jpg
# Loading reference image for filtering
# -----
# check
# [0.39106667]
# extractor
# imwrite
# obama-jpg/138.jpg
# Loading reference image for filtering
# -----
# check
# [0.45083898]
# extractor
# imwrite
# obama-jpg/049.jpg
# Loading reference image for filtering
# -----
# check
# [0.37028016]
# extractor
# imwrite
# obama-jpg/126.jpg
# Loading reference image for filtering
# -----
# check
# [0.3499231]
# extractor
# imwrite
# obama-jpg/026.jpg
# Loading reference image for filtering
# -----
# check
# [0.35606058]
# extractor
# imwrite
# obama-jpg/056.jpg
# Loading reference image for filtering
# -----
# check
# [0.32125552]
# extractor
# imwrite
# obama-jpg/174.jpg
# Loading reference image for filtering
# -----
# check
# [0.30894102]
# extractor
# imwrite
# obama-jpg/063.jpg
# Loading reference image for filtering
# -----
# check
# [0.40706427]
# extractor
# imwrite
# obama-jpg/081.jpg
# Loading reference image for filtering
# -----
# check
# [0.32680615]
# extractor
# imwrite
# obama-jpg/114.jpg
# Loading reference image for filtering
# -----
# check
# [0.26512901]
# extractor
# imwrite
# obama-jpg/137.jpg
# Loading reference image for filtering
# -----
# check
# [0.43300575]
# extractor
# imwrite
# obama-jpg/035.jpg
# Loading reference image for filtering
# -----
# check
# [0.37509]
# extractor
# imwrite
# obama-jpg/129.jpg
# Loading reference image for filtering
# -----
# check
# [0.36675831]
# extractor
# imwrite
# obama-jpg/162.jpg
# Loading reference image for filtering
# -----
# check
# [0.40716654]
# extractor
# imwrite
# obama-jpg/100.jpg
# Loading reference image for filtering
# -----
# check
# [0.43401611]
# extractor
# imwrite
# obama-jpg/011.jpg
# Loading reference image for filtering
# -----
# check
# [0.35175369]
# extractor
# imwrite
# obama-jpg/058.jpg
# Loading reference image for filtering
# -----
# check
# [0.31526445]
# extractor
# imwrite
# obama-jpg/112.jpg
# Loading reference image for filtering
# -----
# check
# [0.29684727]
# extractor
# imwrite
# obama-jpg/180.jpg
# Loading reference image for filtering
# -----
# check
# [0.33593313]
# extractor
# imwrite
# obama-jpg/095.jpg
# Loading reference image for filtering
# -----
# check
# [0.47948997]
# extractor
# imwrite
# obama-jpg/176.jpg
# Loading reference image for filtering
# -----
# check
# [0.44272997]
# extractor
# imwrite
# obama-jpg/037.jpg
# Loading reference image for filtering
# -----
# check
# [0.39063697]
# extractor
# imwrite
# obama-jpg/012.jpg
# Loading reference image for filtering
# -----
# check
# [0.41536272]
# extractor
# imwrite
# obama-jpg/075.jpg
# Loading reference image for filtering
# -----
# check
# [0.40814465]
# extractor
# imwrite
# clinton-jpg/164.jpg
# Loading reference image for filtering
# -----
# check
# [0.456052]
# extractor
# imwrite
# clinton-jpg/043.jpg
# Loading reference image for filtering
# -----
# check
# [0.40102134]
# extractor
# imwrite
# clinton-jpg/030.jpg
# Loading reference image for filtering
# -----
# check
# [0.30984911]
# extractor
# imwrite
# clinton-jpg/091.jpg
# Loading reference image for filtering
# -----
# check
# [0.3175323]
# extractor
# imwrite
# clinton-jpg/006.jpg
# Loading reference image for filtering
# -----
# check
# [0.35116607]
# extractor
# imwrite
# clinton-jpg/102.jpg
# Loading reference image for filtering
# -----
# check
# [0.37616552]
# extractor
# imwrite
# clinton-jpg/167.jpg
# Loading reference image for filtering
# -----
# check
# [0.37268896]
# extractor
# imwrite
# clinton-jpg/172.jpg
# Loading reference image for filtering
# -----
# check
# [0.35351626]
# extractor
# imwrite
# clinton-jpg/122.jpg
# Loading reference image for filtering
# -----
# check
# [0.47607156]
# extractor
# imwrite
# clinton-jpg/130.jpg
# Loading reference image for filtering
# -----
# check
# [0.34674473]
# extractor
# imwrite
# clinton-jpg/189.jpg
# Loading reference image for filtering
# -----
# check
# [0.30693587]
# extractor
# imwrite
# clinton-jpg/092.jpg
# Loading reference image for filtering
# -----
# check
# [0.36344745]
# extractor
# imwrite
# clinton-jpg/053.jpg
# Loading reference image for filtering
# -----
# check
# [0.35459367]
# extractor
# imwrite
# clinton-jpg/099.jpg
# Loading reference image for filtering
# -----
# check
# [0.33986628]
# extractor
# imwrite
# clinton-jpg/032.jpg
# Loading reference image for filtering
# -----
# check
# [0.37133143]
# extractor
# imwrite
# clinton-jpg/117.jpg
# Loading reference image for filtering
# -----
# check
# [0.43689029]
# extractor
# imwrite
# clinton-jpg/178.jpg
# Loading reference image for filtering
# -----
# check
# [0.32942988]
# extractor
# imwrite
# clinton-jpg/152.jpg
# Loading reference image for filtering
# -----
# check
# [0.40820859]
# extractor
# imwrite
# clinton-jpg/101.jpg
# Loading reference image for filtering
# -----
# check
# [0.3738143]
# extractor
# imwrite
# clinton-jpg/115.jpg
# Loading reference image for filtering
# -----
# check
# [0.31413614]
# extractor
# imwrite
# clinton-jpg/074.jpg
# Loading reference image for filtering
# -----
# check
# [0.44751165]
# extractor
# imwrite
# clinton-jpg/168.jpg
# Loading reference image for filtering
# -----
# check
# [0.37764437]
# extractor
# imwrite
# clinton-jpg/177.jpg
# Loading reference image for filtering
# -----
# check
# [0.3660175]
# extractor
# imwrite
# clinton-jpg/066.jpg
# Loading reference image for filtering
# -----
# check
# [0.31623785]
# extractor
# imwrite
# clinton-jpg/192.jpg
# Loading reference image for filtering
# -----
# check
# [0.33586316]
# extractor
# imwrite
# clinton-jpg/136.jpg
# Loading reference image for filtering
# -----
# check
# [0.36319668]
# extractor
# imwrite
# clinton-jpg/087.jpg
# Loading reference image for filtering
# -----
# check
# [0.33278431]
# extractor
# imwrite
# clinton-jpg/161.jpg
# Loading reference image for filtering
# -----
# check
# [0.46323796]
# extractor
# imwrite
# clinton-jpg/153.jpg
# Loading reference image for filtering
# -----
# check
# [0.36363819]
# extractor
# imwrite
# clinton-jpg/104.jpg
# Loading reference image for filtering
# -----
# check
# [0.42295321]
# extractor
# imwrite
# clinton-jpg/007.jpg
# Loading reference image for filtering
# -----
# check
# [0.35235585]
# extractor
# imwrite
# clinton-jpg/042.jpg
# Loading reference image for filtering
# -----
# check
# [0.41289746]
# extractor
# imwrite
# clinton-jpg/036.jpg
# Loading reference image for filtering
# -----
# check
# [0.37330824]
# extractor
# imwrite
# clinton-jpg/120.jpg
# Loading reference image for filtering
# -----
# check
# [0.42817737]
# extractor
# imwrite
# clinton-jpg/076.jpg
# Loading reference image for filtering
# -----
# check
# [0.4123118]
# extractor
# imwrite
# clinton-jpg/055.jpg
# Loading reference image for filtering
# -----
# check
# No faces found in the image!
# 0.8
# Skipping not recognized face!
# clinton-jpg/052.jpg
# Loading reference image for filtering
# -----
# check
# [0.33055924]
# extractor
# imwrite
# clinton-jpg/014.jpg
# Loading reference image for filtering
# -----
# check
# [0.37094832]
# extractor
# imwrite
# clinton-jpg/173.jpg
# Loading reference image for filtering
# -----
# check
# [0.3479862]
# extractor
# imwrite
# clinton-jpg/111.jpg
# Loading reference image for filtering
# -----
# check
# [0.39063086]
# extractor
# imwrite
# clinton-jpg/195.jpg
# Loading reference image for filtering
# -----
# check
# [0.31916075]
# extractor
# imwrite
# clinton-jpg/199.jpg
# Loading reference image for filtering
# -----
# check
# [0.32558596]
# extractor
# imwrite
# clinton-jpg/121.jpg
# Loading reference image for filtering
# -----
# check
# [0.40109546]
# extractor
# imwrite
# clinton-jpg/113.jpg
# Loading reference image for filtering
# -----
# check
# [0.40406488]
# extractor
# imwrite
# clinton-jpg/190.jpg
# Loading reference image for filtering
# -----
# check
# [0.31905976]
# extractor
# imwrite
# clinton-jpg/027.jpg
# Loading reference image for filtering
# -----
# check
# [0.33418986]
# extractor
# imwrite
# clinton-jpg/191.jpg
# Loading reference image for filtering
# -----
# check
# [0.31280582]
# extractor
# imwrite
# clinton-jpg/072.jpg
# Loading reference image for filtering
# -----
# check
# [0.44158474]
# extractor
# imwrite
# clinton-jpg/157.jpg
# Loading reference image for filtering
# -----
# check
# [0.35674983]
# extractor
# imwrite
# clinton-jpg/107.jpg
# Loading reference image for filtering
# -----
# check
# [0.40371155]
# extractor
# imwrite
# clinton-jpg/096.jpg
# Loading reference image for filtering
# -----
# check
# [0.31852302]
# extractor
# imwrite
# clinton-jpg/080.jpg
# Loading reference image for filtering
# -----
# check
# [0.40997281]
# extractor
# imwrite
# clinton-jpg/023.jpg
# Loading reference image for filtering
# -----
# check
# [0.34686816]
# extractor
# imwrite
# clinton-jpg/013.jpg
# Loading reference image for filtering
# -----
# check
# [0.35681147]
# extractor
# imwrite
# clinton-jpg/068.jpg
# Loading reference image for filtering
# -----
# check
# [0.36058561]
# extractor
# imwrite
# clinton-jpg/046.jpg
# Loading reference image for filtering
# -----
# check
# [0.45629991]
# extractor
# imwrite
# clinton-jpg/187.jpg
# Loading reference image for filtering
# -----
# check
# [0.34422606]
# extractor
# imwrite
# clinton-jpg/059.jpg
# Loading reference image for filtering
# -----
# check
# [0.33960661]
# extractor
# imwrite
# clinton-jpg/025.jpg
# Loading reference image for filtering
# -----
# check
# [0.3793964]
# extractor
# imwrite
# clinton-jpg/097.jpg
# Loading reference image for filtering
# -----
# check
# [0.30948776]
# extractor
# imwrite
# clinton-jpg/017.jpg
# Loading reference image for filtering
# -----
# check
# [0.39526765]
# extractor
# imwrite
# clinton-jpg/109.jpg
# Loading reference image for filtering
# -----
# check
# [0.37204635]
# extractor
# imwrite
# clinton-jpg/154.jpg
# Loading reference image for filtering
# -----
# check
# [0.40137006]
# extractor
# imwrite
# clinton-jpg/171.jpg
# Loading reference image for filtering
# -----
# check
# [0.33855055]
# extractor
# imwrite
# clinton-jpg/182.jpg
# Loading reference image for filtering
# -----
# check
# [0.32002076]
# extractor
# imwrite
# clinton-jpg/067.jpg
# Loading reference image for filtering
# -----
# check
# [0.31478473]
# extractor
# imwrite
# clinton-jpg/125.jpg
# Loading reference image for filtering
# -----
# check
# [0.34013564]
# extractor
# imwrite
# clinton-jpg/142.jpg
# Loading reference image for filtering
# -----
# check
# [0.33344372]
# extractor
# imwrite
# clinton-jpg/061.jpg
# Loading reference image for filtering
# -----
# check
# [0.32824001]
# extractor
# imwrite
# clinton-jpg/033.jpg
# Loading reference image for filtering
# -----
# check
# [0.36597545]
# extractor
# imwrite
# clinton-jpg/034.jpg
# Loading reference image for filtering
# -----
# check
# [0.3696931]
# extractor
# imwrite
# clinton-jpg/179.jpg
# Loading reference image for filtering
# -----
# check
# [0.33474336]
# extractor
# imwrite
# clinton-jpg/144.jpg
# Loading reference image for filtering
# -----
# check
# [0.40244487]
# extractor
# imwrite
# clinton-jpg/044.jpg
# Loading reference image for filtering
# -----
# check
# [0.42780196]
# extractor
# imwrite
# clinton-jpg/159.jpg
# Loading reference image for filtering
# -----
# check
# [0.39880618]
# extractor
# imwrite
# clinton-jpg/021.jpg
# Loading reference image for filtering
# -----
# check
# [0.33453406]
# extractor
# imwrite
# clinton-jpg/015.jpg
# Loading reference image for filtering
# -----
# check
# [0.3543523]
# extractor
# imwrite
# clinton-jpg/123.jpg
# Loading reference image for filtering
# -----
# check
# [0.44515312]
# extractor
# imwrite
# clinton-jpg/077.jpg
# Loading reference image for filtering
# -----
# check
# [0.4539268]
# extractor
# imwrite
# clinton-jpg/105.jpg
# Loading reference image for filtering
# -----
# check
# [0.38116594]
# extractor
# imwrite
# clinton-jpg/041.jpg
# Loading reference image for filtering
# -----
# check
# [0.3756204]
# extractor
# imwrite
# clinton-jpg/071.jpg
# Loading reference image for filtering
# -----
# check
# [0.43245403]
# extractor
# imwrite
# clinton-jpg/116.jpg
# Loading reference image for filtering
# -----
# check
# [0.35288045]
# extractor
# imwrite
# clinton-jpg/148.jpg
# Loading reference image for filtering
# -----
# check
# [0.45633013]
# extractor
# imwrite
# clinton-jpg/018.jpg
# Loading reference image for filtering
# -----
# check
# [0.34302146]
# extractor
# imwrite
# clinton-jpg/090.jpg
# Loading reference image for filtering
# -----
# check
# [0.3400579]
# extractor
# imwrite
# clinton-jpg/093.jpg
# Loading reference image for filtering
# -----
# check
# [0.37493558]
# extractor
# imwrite
# clinton-jpg/094.jpg
# Loading reference image for filtering
# -----
# check
# [0.34074169]
# extractor
# imwrite
# clinton-jpg/139.jpg
# Loading reference image for filtering
# -----
# check
# [0.30349793]
# extractor
# imwrite
# clinton-jpg/098.jpg
# Loading reference image for filtering
# -----
# check
# [0.30772591]
# extractor
# imwrite
# clinton-jpg/069.jpg
# Loading reference image for filtering
# -----
# check
# [0.37130927]
# extractor
# imwrite
# clinton-jpg/022.jpg
# Loading reference image for filtering
# -----
# check
# [0.39853425]
# extractor
# imwrite
# clinton-jpg/140.jpg
# Loading reference image for filtering
# -----
# check
# [0.32080271]
# extractor
# imwrite
# clinton-jpg/085.jpg
# Loading reference image for filtering
# -----
# check
# [0.34430105]
# extractor
# imwrite
# clinton-jpg/073.jpg
# Loading reference image for filtering
# -----
# check
# [0.41541588]
# extractor
# imwrite
# clinton-jpg/040.jpg
# Loading reference image for filtering
# -----
# check
# [0.39094549]
# extractor
# imwrite
# clinton-jpg/028.jpg
# Loading reference image for filtering
# -----
# check
# [0.34311178]
# extractor
# imwrite
# clinton-jpg/002.jpg
# Loading reference image for filtering
# -----
# check
# [0.31903337]
# extractor
# imwrite
# clinton-jpg/143.jpg
# Loading reference image for filtering
# -----
# check
# [0.30955261]
# extractor
# imwrite
# clinton-jpg/008.jpg
# Loading reference image for filtering
# -----
# check
# [0.31676241]
# extractor
# imwrite
# clinton-jpg/019.jpg
# Loading reference image for filtering
# -----
# check
# [0.32027711]
# extractor
# imwrite
# clinton-jpg/158.jpg
# Loading reference image for filtering
# -----
# check
# [0.38251894]
# extractor
# imwrite
# clinton-jpg/165.jpg
# Loading reference image for filtering
# -----
# check
# [0.41347336]
# extractor
# imwrite
# clinton-jpg/083.jpg
# Loading reference image for filtering
# -----
# check
# [0.31598157]
# extractor
# imwrite
# clinton-jpg/194.jpg
# Loading reference image for filtering
# -----
# check
# [0.33574002]
# extractor
# imwrite
# clinton-jpg/185.jpg
# Loading reference image for filtering
# -----
# check
# [0.28808369]
# extractor
# imwrite
# clinton-jpg/166.jpg
# Loading reference image for filtering
# -----
# check
# [0.43914973]
# extractor
# imwrite
# clinton-jpg/010.jpg
# Loading reference image for filtering
# -----
# check
# [0.33359078]
# extractor
# imwrite
# clinton-jpg/062.jpg
# Loading reference image for filtering
# -----
# check
# [0.29141869]
# extractor
# imwrite
# clinton-jpg/078.jpg
# Loading reference image for filtering
# -----
# check
# [0.46876696]
# extractor
# imwrite
# clinton-jpg/005.jpg
# Loading reference image for filtering
# -----
# check
# [0.31660824]
# extractor
# imwrite
# clinton-jpg/016.jpg
# Loading reference image for filtering
# -----
# check
# [0.38534596]
# extractor
# imwrite
# clinton-jpg/084.jpg
# Loading reference image for filtering
# -----
# check
# [0.3174871]
# extractor
# imwrite
# clinton-jpg/060.jpg
# Loading reference image for filtering
# -----
# check
# [0.22155816]
# extractor
# imwrite
# clinton-jpg/079.jpg
# Loading reference image for filtering
# -----
# check
# [0.4773341]
# extractor
# imwrite
# clinton-jpg/086.jpg
# Loading reference image for filtering
# -----
# check
# [0.31138765]
# extractor
# imwrite
# clinton-jpg/038.jpg
# Loading reference image for filtering
# -----
# check
# [0.40549009]
# extractor
# imwrite
# clinton-jpg/001.jpg
# Loading reference image for filtering
# -----
# check
# [0.40468216]
# extractor
# imwrite
# clinton-jpg/184.jpg
# Loading reference image for filtering
# -----
# check
# [0.33330589]
# extractor
# imwrite
# clinton-jpg/064.jpg
# Loading reference image for filtering
# -----
# check
# [0.29325619]
# extractor
# imwrite
# clinton-jpg/196.jpg
# Loading reference image for filtering
# -----
# check
# [0.30254005]
# extractor
# imwrite
# clinton-jpg/054.jpg
# Loading reference image for filtering
# -----
# check
# [0.30332726]
# extractor
# imwrite
# clinton-jpg/047.jpg
# Loading reference image for filtering
# -----
# check
# [0.42128704]
# extractor
# imwrite
# clinton-jpg/132.jpg
# Loading reference image for filtering
# -----
# check
# [0.36271706]
# extractor
# imwrite
# clinton-jpg/020.jpg
# Loading reference image for filtering
# -----
# check
# [0.38641169]
# extractor
# imwrite
# clinton-jpg/175.jpg
# Loading reference image for filtering
# -----
# check
# [0.3441244]
# extractor
# imwrite
# clinton-jpg/118.jpg
# Loading reference image for filtering
# -----
# check
# No faces found in the image!
# 0.8
# Skipping not recognized face!
# clinton-jpg/134.jpg
# Loading reference image for filtering
# -----
# check
# [0.35615424]
# extractor
# imwrite
# clinton-jpg/103.jpg
# Loading reference image for filtering
# -----
# check
# [0.49567211]
# extractor
# imwrite
# clinton-jpg/106.jpg
# Loading reference image for filtering
# -----
# check
# [0.44409665]
# extractor
# imwrite
# clinton-jpg/131.jpg
# Loading reference image for filtering
# -----
# check
# [0.33875206]
# extractor
# imwrite
# clinton-jpg/045.jpg
# Loading reference image for filtering
# -----
# check
# [0.40397493]
# extractor
# imwrite
# clinton-jpg/050.jpg
# Loading reference image for filtering
# -----
# check
# [0.36582927]
# extractor
# imwrite
# clinton-jpg/024.jpg
# Loading reference image for filtering
# -----
# check
# [0.34258329]
# extractor
# imwrite
# clinton-jpg/170.jpg
# Loading reference image for filtering
# -----
# check
# [0.36545687]
# extractor
# imwrite
# clinton-jpg/156.jpg
# Loading reference image for filtering
# -----
# check
# [0.39785618]
# extractor
# imwrite
# clinton-jpg/146.jpg
# Loading reference image for filtering
# -----
# check
# [0.37097822]
# extractor
# imwrite
# clinton-jpg/145.jpg
# Loading reference image for filtering
# -----
# check
# [0.38487726]
# extractor
# imwrite
# clinton-jpg/163.jpg
# Loading reference image for filtering
# -----
# check
# [0.44459537]
# extractor
# imwrite
# clinton-jpg/183.jpg
# Loading reference image for filtering
# -----
# check
# [0.33424269]
# extractor
# imwrite
# clinton-jpg/169.jpg
# Loading reference image for filtering
# -----
# check
# [0.37187771]
# extractor
# imwrite
# clinton-jpg/151.jpg
# Loading reference image for filtering
# -----
# check
# [0.40448464]
# extractor
# imwrite
# clinton-jpg/181.jpg
# Loading reference image for filtering
# -----
# check
# [0.26494152]
# extractor
# imwrite
# clinton-jpg/186.jpg
# Loading reference image for filtering
# -----
# check
# [0.40428524]
# extractor
# imwrite
# clinton-jpg/051.jpg
# Loading reference image for filtering
# -----
# check
# [0.31774388]
# extractor
# imwrite
# clinton-jpg/009.jpg
# Loading reference image for filtering
# -----
# check
# [0.35927215]
# extractor
# imwrite
# clinton-jpg/198.jpg
# Loading reference image for filtering
# -----
# check
# [0.3185063]
# extractor
# imwrite
# clinton-jpg/149.jpg
# Loading reference image for filtering
# -----
# check
# [0.42565241]
# extractor
# imwrite
# clinton-jpg/065.jpg
# Loading reference image for filtering
# -----
# check
# [0.32381641]
# extractor
# imwrite
# clinton-jpg/193.jpg
# Loading reference image for filtering
# -----
# check
# [0.32307001]
# extractor
# imwrite
# clinton-jpg/039.jpg
# Loading reference image for filtering
# -----
# check
# [0.33280077]
# extractor
# imwrite
# clinton-jpg/004.jpg
# Loading reference image for filtering
# -----
# check
# [0.34288178]
# extractor
# imwrite
# clinton-jpg/201.jpg
# Loading reference image for filtering
# -----
# check
# [0.36287768]
# extractor
# imwrite
# clinton-jpg/048.jpg
# Loading reference image for filtering
# -----
# check
# [0.35759178]
# extractor
# imwrite
# clinton-jpg/160.jpg
# Loading reference image for filtering
# -----
# check
# [0.33602105]
# extractor
# imwrite
# clinton-jpg/003.jpg
# Loading reference image for filtering
# -----
# check
# [0.32253446]
# extractor
# imwrite
# clinton-jpg/188.jpg
# Loading reference image for filtering
# -----
# check
# [0.32038531]
# extractor
# imwrite
# clinton-jpg/082.jpg
# Loading reference image for filtering
# -----
# check
# [0.2676045]
# extractor
# imwrite
# clinton-jpg/110.jpg
# Loading reference image for filtering
# -----
# check
# [0.29529858]
# extractor
# imwrite
# clinton-jpg/119.jpg
# Loading reference image for filtering
# -----
# check
# [0.4585581]
# extractor
# imwrite
# clinton-jpg/031.jpg
# Loading reference image for filtering
# -----
# check
# [0.274448]
# extractor
# imwrite
# clinton-jpg/124.jpg
# Loading reference image for filtering
# -----
# check
# [0.39782104]
# extractor
# imwrite
# clinton-jpg/128.jpg
# Loading reference image for filtering
# -----
# check
# [0.33305657]
# extractor
# imwrite
# clinton-jpg/135.jpg
# Loading reference image for filtering
# -----
# check
# [0.35175567]
# extractor
# imwrite
# clinton-jpg/070.jpg
# Loading reference image for filtering
# -----
# check
# [0.3934317]
# extractor
# imwrite
# clinton-jpg/108.jpg
# Loading reference image for filtering
# -----
# check
# [0.39240624]
# extractor
# imwrite
# clinton-jpg/147.jpg
# Loading reference image for filtering
# -----
# check
# [0.44936055]
# extractor
# imwrite
# clinton-jpg/127.jpg
# Loading reference image for filtering
# -----
# check
# [0.34734447]
# extractor
# imwrite
# clinton-jpg/057.jpg
# Loading reference image for filtering
# -----
# check
# [0.34144345]
# extractor
# imwrite
# clinton-jpg/133.jpg
# Loading reference image for filtering
# -----
# check
# [0.30534218]
# extractor
# imwrite
# clinton-jpg/089.jpg
# Loading reference image for filtering
# -----
# check
# [0.32612253]
# extractor
# imwrite
# clinton-jpg/150.jpg
# Loading reference image for filtering
# -----
# check
# [0.48057097]
# extractor
# imwrite
# clinton-jpg/088.jpg
# Loading reference image for filtering
# -----
# check
# [0.33528401]
# extractor
# imwrite
# clinton-jpg/141.jpg
# Loading reference image for filtering
# -----
# check
# [0.31267024]
# extractor
# imwrite
# clinton-jpg/155.jpg
# Loading reference image for filtering
# -----
# check
# [0.32379125]
# extractor
# imwrite
# clinton-jpg/029.jpg
# Loading reference image for filtering
# -----
# check
# [0.36707248]
# extractor
# imwrite
# clinton-jpg/138.jpg
# Loading reference image for filtering
# -----
# check
# [0.33514095]
# extractor
# imwrite
# clinton-jpg/049.jpg
# Loading reference image for filtering
# -----
# check
# [0.35594723]
# extractor
# imwrite
# clinton-jpg/126.jpg
# Loading reference image for filtering
# -----
# check
# [0.33196523]
# extractor
# imwrite
# clinton-jpg/026.jpg
# Loading reference image for filtering
# -----
# check
# [0.37372383]
# extractor
# imwrite
# clinton-jpg/202.jpg
# Loading reference image for filtering
# -----
# check
# [0.35447865]
# extractor
# imwrite
# clinton-jpg/056.jpg
# Loading reference image for filtering
# -----
# check
# [0.32367007]
# extractor
# imwrite
# clinton-jpg/174.jpg
# Loading reference image for filtering
# -----
# check
# [0.36563016]
# extractor
# imwrite
# clinton-jpg/197.jpg
# Loading reference image for filtering
# -----
# check
# [0.32396656]
# extractor
# imwrite
# clinton-jpg/063.jpg
# Loading reference image for filtering
# -----
# check
# [0.29526008]
# extractor
# imwrite
# clinton-jpg/081.jpg
# Loading reference image for filtering
# -----
# check
# [0.418714]
# extractor
# imwrite
# clinton-jpg/114.jpg
# Loading reference image for filtering
# -----
# check
# [0.36292749]
# extractor
# imwrite
# clinton-jpg/137.jpg
# Loading reference image for filtering
# -----
# check
# [0.35339461]
# extractor
# imwrite
# clinton-jpg/200.jpg
# Loading reference image for filtering
# -----
# check
# [0.36304729]
# extractor
# imwrite
# clinton-jpg/035.jpg
# Loading reference image for filtering
# -----
# check
# [0.37354074]
# extractor
# imwrite
# clinton-jpg/129.jpg
# Loading reference image for filtering
# -----
# check
# [0.3358257]
# extractor
# imwrite
# clinton-jpg/162.jpg
# Loading reference image for filtering
# -----
# check
# [0.48426397]
# extractor
# imwrite
# clinton-jpg/100.jpg
# Loading reference image for filtering
# -----
# check
# [0.30052399]
# extractor
# imwrite
# clinton-jpg/011.jpg
# Loading reference image for filtering
# -----
# check
# [0.33703521]
# extractor
# imwrite
# clinton-jpg/058.jpg
# Loading reference image for filtering
# -----
# check
# [0.33269068]
# extractor
# imwrite
# clinton-jpg/112.jpg
# Loading reference image for filtering
# -----
# check
# [0.36539001]
# extractor
# imwrite
# clinton-jpg/180.jpg
# Loading reference image for filtering
# -----
# check
# [0.34811416]
# extractor
# imwrite
# clinton-jpg/095.jpg
# Loading reference image for filtering
# -----
# check
# [0.34356595]
# extractor
# imwrite
# clinton-jpg/176.jpg
# Loading reference image for filtering
# -----
# check
# [0.37771112]
# extractor
# imwrite
# clinton-jpg/037.jpg
# Loading reference image for filtering
# -----
# check
# [0.36820442]
# extractor
# imwrite
# clinton-jpg/012.jpg
# Loading reference image for filtering
# -----
# check
# [0.32821601]
# extractor
# imwrite
# clinton-jpg/075.jpg
# Loading reference image for filtering
# -----
# check
# [0.40690108]
# extractor
# imwrite

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mp_image

img = mp_image.imread('clinton-jpg/076.jpg')
plt.imshow(img)
plt.show()
img = mp_image.imread('clinton-cut/0760.jpg')
plt.imshow(img)
plt.show()
img = mp_image.imread('obama-jpg/076.jpg')
plt.imshow(img)
plt.show()
img = mp_image.imread('obama-cut/0760.jpg')
plt.imshow(img)
plt.show()

# %% [markdown]
# ## 학습하기

# %%
import gdown
md5 = 'd1b5f39e88b70cd3661b73b36f296586'  
# pretrained weights for speed up
url = 'https://drive.google.com/uc?id=1biKvZSxV-Dx9mUX-UMaFcZ6J8OMQ9MHQ'
output = 'weights2.zip'
gdown.cached_download(url, output, md5=md5)
# Out:
# Cached Downloading: weights2.zip
# Downloading...
# From: https://drive.google.com/uc?id=1biKvZSxV-Dx9mUX-UMaFcZ6J8OMQ9MHQ
# To: /root/.cache/gdown/tmpwy3j4lnm/dl
# 304MB [00:04, 61.9MB/s]
# Computing MD5: weights2.zip
# MD5 matches: weights2.zip
# 'weights2.zip'

# %%
# !unzip weights2.zip
# Out:
# Archive:  weights2.zip
#    creating: weight/
#   inflating: weight/decoder_A.h5
#   inflating: weight/decoder_B.h5
#   inflating: weight/encoder.h5

# %%
import cv2
import numpy
import time

from pathlib import Path
from scandir import scandir

from keras.models import Model as KerasModel
from keras.layers import Input, Dense, Flatten, Reshape
from keras.layers.advanced_activations import LeakyReLU
from keras.layers.convolutional import Conv2D
# from keras.optimizers import Adam
# from tensorflow.python.keras.optimizer_v2.adam import Adam
from tensorflow.keras.optimizers import Adam

from lib_1.PixelShuffler import PixelShuffler
import time
import numpy
from lib_1.training_data import minibatchAB, stack_images

# %%
sav_Model="saved_model"
pretrained_weight="weight"
# 계속해서 train할 경우 아래의 저장 폴더를 이용
#pretrained_weight="saved_model"
image_actor_A_directory="obama-cut" #ORIGINAL
image_actor_B_directory="clinton-cut" #TARGET TO REPLACE WITH
batch_size=32
save_interval=500
ENCODER_DIM = 1024


#DON'T MODIFY
image_extensions = [".jpg", ".jpeg", ".png"]
encoderH5 = '/encoder.h5'
decoder_AH5 = '/decoder_A.h5'
decoder_BH5 = '/decoder_B.h5'
IMAGE_SHAPE = (64, 64, 3)

# %%
class dfModel():
    def __init__(self):
        self.model_dir = sav_Model
        self.pretrained_weight=pretrained_weight
        self.encoder = self.Encoder()
        self.decoder_A = self.Decoder()
        self.decoder_B = self.Decoder()

        self.initModel()

    def initModel(self):
        optimizer = Adam(lr=5e-5, beta_1=0.5, beta_2=0.999) #orig adam 5e-5
        x = Input(shape=IMAGE_SHAPE)

        self.autoencoder_A = KerasModel(x, self.decoder_A(self.encoder(x)))
        self.autoencoder_B = KerasModel(x, self.decoder_B(self.encoder(x)))
        print(self.encoder.summary())
        print(self.decoder_A.summary())

        self.autoencoder_A.compile(optimizer=optimizer, loss='mean_absolute_error')
        self.autoencoder_B.compile(optimizer=optimizer, loss='mean_absolute_error')

    def converter(self, swap):
        autoencoder = self.autoencoder_B if not swap else self.autoencoder_A
        return lambda img: autoencoder.predict(img)

    def conv(self, filters):
        def block(x):
            x = Conv2D(filters, kernel_size=5, strides=2, padding='same')(x)
            x = LeakyReLU(0.1)(x)
            return x
        return block

    def upscale(self, filters):
        def block(x):
            x = Conv2D(filters * 4, kernel_size=3, padding='same')(x)
            x = LeakyReLU(0.1)(x)
            x = PixelShuffler()(x)
            #Pixelshufflers job here is analoguous to upsampling2d
            return x
        return block

    #Note how no maxpooling after every layer here, we are generating a WARPED image, not a lower dimensional representation first.
    def Encoder(self):
        input_ = Input(shape=IMAGE_SHAPE)
        x = input_
        x = self.conv(128)(x)
        x = self.conv(256)(x)
        x = self.conv(512)(x)
        x = self.conv(1024)(x)
        x = Dense(ENCODER_DIM)(Flatten()(x))
        x = Dense(4 * 4 * 1024)(x)
        #Passed flattened X input into 2 dense layers, 1024 and 1024*4*4
        x = Reshape((4, 4, 1024))(x)
        #Reshapes X into 4,4,1024
        x = self.upscale(512)(x)
        return KerasModel(input_, x)

    def Decoder(self):
        input_ = Input(shape=(8, 8, 512))
        x = input_
        x = self.upscale(256)(x) #Actually 1024 given filters*4
        x = self.upscale(128)(x) #Actually 512
        x = self.upscale(64)(x) #Actually 256
        x = Conv2D(3, kernel_size=5, padding='same', activation='sigmoid')(x)
        return KerasModel(input_, x)

    def load(self, swapped):
        (face_A,face_B) = (decoder_AH5, decoder_BH5) if not swapped else (decoder_BH5, decoder_AH5)
        try:
            self.encoder.load_weights(self.pretrained_weight + encoderH5)
            self.decoder_A.load_weights(self.pretrained_weight + face_A)
            self.decoder_B.load_weights(self.pretrained_weight + face_B)
            print('loaded model weights')
            return True
        except Exception as e:
            print('Failed loading existing training data.')
            print(e)
            return False
            
    def save_weights(self):
        self.encoder.save_weights(self.model_dir + encoderH5)
        self.decoder_A.save_weights(self.model_dir + decoder_AH5)
        self.decoder_B.save_weights(self.model_dir + decoder_BH5)
        print('saved model weights')

# %%
class Trainer():
    def __init__(self, model, fn_A, fn_B, batch_size=64):
        self.batch_size = batch_size
        self.model = model
        self.images_A = minibatchAB(fn_A, self.batch_size)
        self.images_B = minibatchAB(fn_B, self.batch_size)

    def train_one_step(self, iter):
        epoch, warped_A, target_A = next(self.images_A)
        epoch, warped_B, target_B = next(self.images_B)

        loss_A = self.model.autoencoder_A.train_on_batch(warped_A, target_A)
        loss_B = self.model.autoencoder_B.train_on_batch(warped_B, target_B)
        print("[{0}] [#{1:05d}] loss_A: {2:.5f}, loss_B: {3:.5f}".format(time.strftime("%H:%M:%S"), iter, loss_A, loss_B),
            end='\r')

# %%
def get_image_paths(directory):
    return [x.path for x in scandir(directory) if
     any(map(lambda ext: x.name.lower().endswith(ext), image_extensions))]

# %%
model = dfModel()
model.load(swapped=False)
# Out:
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/optimizer_v2/optimizer_v2.py:375: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   "The `lr` argument is deprecated, use `learning_rate` instead.")
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 64, 64, 3)]       0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 32, 32, 128)       9728
# _________________________________________________________________
# leaky_re_lu (LeakyReLU)      (None, 32, 32, 128)       0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 16, 16, 256)       819456
# _________________________________________________________________
# leaky_re_lu_1 (LeakyReLU)    (None, 16, 16, 256)       0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 8, 8, 512)         3277312
# _________________________________________________________________
# leaky_re_lu_2 (LeakyReLU)    (None, 8, 8, 512)         0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 4, 4, 1024)        13108224
# _________________________________________________________________
# leaky_re_lu_3 (LeakyReLU)    (None, 4, 4, 1024)        0
# _________________________________________________________________
# flatten (Flatten)            (None, 16384)             0
# _________________________________________________________________
# dense (Dense)                (None, 1024)              16778240
# _________________________________________________________________
# dense_1 (Dense)              (None, 16384)             16793600
# _________________________________________________________________
# reshape (Reshape)            (None, 4, 4, 1024)        0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 4, 4, 2048)        18876416
# _________________________________________________________________
# leaky_re_lu_4 (LeakyReLU)    (None, 4, 4, 2048)        0
# _________________________________________________________________
# pixel_shuffler (PixelShuffle (None, 8, 8, 512)         0
# =================================================================
# Total params: 69,662,976
# Trainable params: 69,662,976
# Non-trainable params: 0
# _________________________________________________________________
# None
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, 8, 8, 512)]       0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 8, 8, 1024)        4719616
# _________________________________________________________________
# leaky_re_lu_5 (LeakyReLU)    (None, 8, 8, 1024)        0
# _________________________________________________________________
# pixel_shuffler_1 (PixelShuff (None, 16, 16, 256)       0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 16, 16, 512)       1180160
# _________________________________________________________________
# leaky_re_lu_6 (LeakyReLU)    (None, 16, 16, 512)       0
# _________________________________________________________________
# pixel_shuffler_2 (PixelShuff (None, 32, 32, 128)       0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 32, 32, 256)       295168
# _________________________________________________________________
# leaky_re_lu_7 (LeakyReLU)    (None, 32, 32, 256)       0
# _________________________________________________________________
# pixel_shuffler_3 (PixelShuff (None, 64, 64, 64)        0
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 64, 64, 3)         4803
# =================================================================
# Total params: 6,199,747
# Trainable params: 6,199,747
# Non-trainable params: 0
# _________________________________________________________________
# None
# loaded model weights
# True

# %%
images_A = get_image_paths(image_actor_A_directory)
images_B = get_image_paths(image_actor_B_directory)
trainer = Trainer(model,images_A,images_B,batch_size=batch_size)

for epoch in range(0, 1000000):

    save_iteration = epoch % save_interval == 0

    trainer.train_one_step(epoch)

    if save_iteration:
        print('epoch =', epoch)
        model.save_weights()
# Out:
# epoch = 0
# saved model weights
# epoch = 500
# saved model weights
# epoch = 1000
# saved model weights
# epoch = 1500
# saved model weights
# epoch = 2000
# saved model weights
# epoch = 2500
# saved model weights
# epoch = 3000
# saved model weights
# epoch = 3500
# saved model weights
# epoch = 4000
# saved model weights
# epoch = 4500
# saved model weights
# epoch = 5000
# saved model weights
# epoch = 5500
# saved model weights
# epoch = 6000
# saved model weights
# epoch = 6500
# saved model weights
# epoch = 7000
# saved model weights
# epoch = 7500
# saved model weights
# epoch = 8000
# saved model weights
# epoch = 8500
# saved model weights
# epoch = 9000
# saved model weights
# epoch = 9500
# saved model weights
# epoch = 10000
# saved model weights
# epoch = 10500
# saved model weights
# epoch = 11000
# saved model weights
# epoch = 11500
# saved model weights
# epoch = 12000
# saved model weights
# epoch = 12500
# saved model weights
# epoch = 13000
# saved model weights
# epoch = 13500
# saved model weights
# epoch = 14000
# saved model weights
# epoch = 14500
# saved model weights
# epoch = 15000
# saved model weights
# epoch = 15500
# saved model weights
# epoch = 16000
# saved model weights
# epoch = 16500
# saved model weights
# epoch = 17000
# saved model weights
# epoch = 17500
# saved model weights
# epoch = 18000
# saved model weights
# epoch = 18500
# saved model weights
# epoch = 19000
# saved model weights
# epoch = 19500
# saved model weights
# epoch = 20000
# saved model weights
# epoch = 20500
# saved model weights
# epoch = 21000
# saved model weights
# epoch = 21500
# saved model weights
# epoch = 22000
# saved model weights
# epoch = 22500
# saved model weights
# epoch = 23000
# saved model weights
# epoch = 23500
# saved model weights
# epoch = 24000
# saved model weights
# epoch = 24500
# saved model weights
# epoch = 25000
# saved model weights
# epoch = 25500
# saved model weights
# epoch = 26000
# saved model weights
# epoch = 26500
# saved model weights
# epoch = 27000
# saved model weights
# epoch = 27500
# saved model weights
# epoch = 28000
# saved model weights
# epoch = 28500
# saved model weights
# epoch = 29000
# saved model weights
# epoch = 29500
# saved model weights
# epoch = 30000
# saved model weights
# epoch = 30500
# saved model weights
# epoch = 31000
# saved model weights
# epoch = 31500
# saved model weights
# epoch = 32000
# saved model weights
# epoch = 32500
# saved model weights
# epoch = 33000
# saved model weights
# epoch = 33500
# saved model weights
# epoch = 34000
# saved model weights
# epoch = 34500
# saved model weights
# epoch = 35000
# saved model weights
# epoch = 35500
# saved model weights
# epoch = 36000
# saved model weights
# epoch = 36500
# saved model weights
# epoch = 37000
# saved model weights
# epoch = 37500
# saved model weights
# epoch = 38000
# saved model weights
# epoch = 38500
# saved model weights
# epoch = 39000
# saved model weights
# epoch = 39500
# saved model weights
# epoch = 40000
# saved model weights
# epoch = 40500
# saved model weights
# epoch = 41000
# saved model weights
# epoch = 41500
# saved model weights
# epoch = 42000
# saved model weights
# epoch = 42500
# saved model weights
# epoch = 43000
# saved model weights
# epoch = 43500
# saved model weights
# epoch = 44000
# saved model weights
# epoch = 44500
# saved model weights
# epoch = 45000
# saved model weights
# epoch = 45500
# saved model weights
# epoch = 46000
# saved model weights
# epoch = 46500
# saved model weights
# epoch = 47000
# saved model weights
# epoch = 47500
# saved model weights
# epoch = 48000
# saved model weights
# epoch = 48500
# saved model weights
# epoch = 49000
# saved model weights
# epoch = 49500
# saved model weights
# epoch = 50000
# saved model weights
# epoch = 50500
# saved model weights
# epoch = 51000
# saved model weights
# epoch = 51500
# saved model weights
# epoch = 52000
# saved model weights
# epoch = 52500
# saved model weights
# epoch = 53000
# saved model weights
# epoch = 53500
# saved model weights
# epoch = 54000
# saved model weights
# epoch = 54500
# saved model weights
# epoch = 55000
# saved model weights
# epoch = 55500
# saved model weights
# epoch = 56000
# saved model weights
# epoch = 56500
# saved model weights
# epoch = 57000
# saved model weights
# epoch = 57500
# saved model weights
# epoch = 58000
# saved model weights
# epoch = 58500
# saved model weights
# epoch = 59000
# saved model weights
# epoch = 59500
# saved model weights
# epoch = 60000
# saved model weights
# epoch = 60500
# saved model weights
# epoch = 61000
# saved model weights
# epoch = 61500
# saved model weights
# epoch = 62000
# saved model weights
# epoch = 62500
# saved model weights
# epoch = 63000
# saved model weights
# epoch = 63500
# saved model weights
# epoch = 64000
# saved model weights
# epoch = 64500
# saved model weights
# epoch = 65000
# saved model weights
# epoch = 65500
# saved model weights
# epoch = 66000
# saved model weights
# epoch = 66500
# saved model weights
# epoch = 67000
# saved model weights
# epoch = 67500
# saved model weights
# epoch = 68000
# saved model weights
# epoch = 68500
# saved model weights
# epoch = 69000
# saved model weights
# epoch = 69500
# saved model weights
# epoch = 70000
# saved model weights
# epoch = 70500
# saved model weights
# epoch = 71000
# saved model weights
# epoch = 71500
# saved model weights
# epoch = 72000
# saved model weights
# epoch = 72500
# saved model weights
# epoch = 73000
# saved model weights
# epoch = 73500
# saved model weights
# epoch = 74000
# saved model weights
# epoch = 74500
# saved model weights
# epoch = 75000
# saved model weights
# epoch = 75500
# saved model weights
# epoch = 76000
# saved model weights
# epoch = 76500
# saved model weights
# epoch = 77000
# saved model weights
# epoch = 77500
# saved model weights
# epoch = 78000
# saved model weights
# epoch = 78500
# saved model weights
# epoch = 79000
# saved model weights
# epoch = 79500
# saved model weights
# epoch = 80000
# saved model weights
# epoch = 80500
# saved model weights
# epoch = 81000
# saved model weights
# epoch = 81500
# saved model weights
# epoch = 82000
# saved model weights
# epoch = 82500
# saved model weights
# epoch = 83000
# saved model weights
# epoch = 83500
# saved model weights
# epoch = 84000
# saved model weights

# %% [markdown]
# ## 생성하기

# %%
import gdown
md5 = 'b2b747e22727313ed5f64323a6e041ee'  
# 학습하기
url = 'https://drive.google.com/uc?id=1DbGpF_nhVJMeRaVcSVZRh1I1xfp7_dAj'
output = 'saved_model_obama.tar.gz'
gdown.cached_download(url, output, md5=md5)

# %%
# !tar xvzf saved_model_obama.tar.gz

# %%
import cv2
import re
from pathlib import Path
from lib_1.utils import BackgroundGenerator, get_image_paths, get_folder
from lib_1.faces_detect import detect_faces
from lib_1.FaceFilter import FaceFilter
from tqdm import tqdm
from lib_1.PluginLoader import PluginLoader

#os.run_line_magic('pylab', 'inline')
import matplotlib.pyplot as plt

from keras.models import Model as KerasModel
from keras.layers import Input, Dense, Flatten, Reshape
from keras.layers.advanced_activations import LeakyReLU
from keras.layers.convolutional import Conv2D
from keras.optimizers import Adam
from lib_1.PixelShuffler import PixelShuffler

# %%
# We define the caracteristics of our network:
#    * model_dir: the location of the model (it needs to be the absolute path)
#    * conv_name: the kind of converter to use ("Masked" or "Adjust")
#    * swap_model: Swap the model. Instead of A -> B, swap B -> A.
#    * blur_size: Blur size. (it only work for Masked converter)
#    * seamless_clone: Seamless mode
#    * mask_type: the type of mask to use to replace faces.("rect", "facehull", "facehullandrect")
#    * erosion_kernel_size: the erosion kernel size. (it only work for the masked converter)
#    * smooth_mask: use Smooth mask (it only work for the Adjust converter)
#    * avg_color_adjust: average the color (it only work for the Adjust converter)
#    * input_dir: the location of the input images (it needs to be the absolute path)
#    * output_dir: the location of the output images (it needs to be the absolute path)
#    * filter_image: the image that will be used to filter faces 
#    
# I invite you to try different parameter until you get a satifying result.

#model_dir="saved_model"
#model_dir="weights" # 누구일까요?
model_dir='saved_model_obama'
conv_name = "Masked"
swap_model= False
blur_size=2
#seamless_clone=False
seamless_clone=True
mask_type="facehullandrect"
erosion_kernel_size=None
smooth_mask=True
avg_color_adjust=True
input_dir="obama-jpg"
output_dir="test"
filter_image="filter/obamafilter.jpg"

# %%
#DONT MODIFY 
IMAGE_SHAPE = (64, 64, 3)
ENCODER_DIM = 1024
encoderH5 = '/encoder.h5'
decoder_AH5 = '/decoder_A.h5'
decoder_BH5 = '/decoder_B.h5'
model_name = "Original" # TODO Pass as argument

# %%
def load_filter():
    filter_file = filter_image # TODO Pass as argument
    if Path(filter_file).exists():
        print('Loading reference image for filtering')
        return FaceFilter(filter_file)

def get_faces(image):
    faces_count = 0
    filterDeepFake = load_filter()
    extractor = PluginLoader.get_extractor("Align")()
    for face in detect_faces(image):
        if filterDeepFake is not None and not filterDeepFake.check(face):
            print('Skipping not recognized face!')
            continue
        resized_image = extractor.extract(image, face, 256)

        yield faces_count, face
        faces_count +=1

def get_list_images_faces():
    input_list = get_image_paths(input_dir)
    listFile=[]
    for filename in tqdm(input_list):
        listFile.append(filename)
    for filename in listFile:
        image = cv2.imread(filename)
        yield filename, image, get_faces(image)

# %% [markdown]
# `converter.patch_image(image, face)` 함수를 통하여 모델을 실행

# %%
def convert(converter, item):
    try:
        (filename, image, faces) = item
        for idx, face in faces:
            image1 = converter.patch_image(image, face)
        output_file = str(output_dir)+ str("/")+ str(Path(filename).name)

        cv2.imwrite(str(output_file), image1)
    except Exception as e:
        print('Failed to convert image: {}. Reason: {}'.format(filename, e))

# %% [markdown]
# `lib_1/Convert_Masked.py` 발췌본

# %%
import cv2
import numpy

from lib_1.aligner import get_align_mat

class Convert():
    def __init__(self, encoder, blur_size=2, seamless_clone=False, mask_type="facehullandrect", erosion_kernel_size=None, **kwargs):
        self.encoder = encoder

        self.erosion_kernel = None
        if erosion_kernel_size is not None:
            self.erosion_kernel = cv2.getStructuringElement(cv2.MORPH_ELLIPSE,(erosion_kernel_size,erosion_kernel_size))

        self.blur_size = blur_size
        self.seamless_clone = seamless_clone
        self.mask_type = mask_type.lower() # Choose in 'FaceHullAndRect','FaceHull','Rect'

    def patch_image( self, image, face_detected ):
        size = 64
        image_size = image.shape[1], image.shape[0]

        mat = numpy.array(get_align_mat(face_detected)).reshape(2,3) * size

        new_face = self.get_new_face(image,mat,size)

        image_mask = self.get_image_mask( image, new_face, face_detected, mat, image_size )

        return self.apply_new_face(image, new_face, image_mask, mat, image_size, size)

    def apply_new_face(self, image, new_face, image_mask, mat, image_size, size):
        base_image = numpy.copy( image )
        new_image = numpy.copy( image )

        outImage = None
        if self.seamless_clone:
            masky,maskx = cv2.transform( numpy.array([ size/2,size/2 ]).reshape(1,1,2) ,cv2.invertAffineTransform(mat) ).reshape(2).astype(int)
            outimage = cv2.seamlessClone(new_image.astype(numpy.uint8),base_image.astype(numpy.uint8),(image_mask*255).astype(numpy.uint8),(masky,maskx) , cv2.NORMAL_CLONE )
        else:
            foreground = cv2.multiply(image_mask, new_image.astype(float))
            background = cv2.multiply(1.0 - image_mask, base_image.astype(float))
            outimage = cv2.add(foreground, background)

        return outimage

    def get_new_face(self, image, mat, size):
        face = cv2.warpAffine( image, mat, (size,size) )
        face = numpy.expand_dims( face, 0 )
        new_face = self.encoder( face / 255.0 )[0]

        return numpy.clip( new_face * 255, 0, 255 ).astype( image.dtype )

    def get_image_mask(self, image, new_face, face_detected, mat, image_size):

        face_mask = numpy.zeros(image.shape,dtype=float)
        if 'rect' in self.mask_type:
            face_src = numpy.ones(new_face.shape,dtype=float)
            cv2.warpAffine( face_src, mat, image_size, face_mask, cv2.WARP_INVERSE_MAP, cv2.BORDER_TRANSPARENT )

        hull_mask = numpy.zeros(image.shape,dtype=float)
        if 'hull' in self.mask_type:
            hull = cv2.convexHull( numpy.array( face_detected.landmarksAsXY() ).reshape((-1,2)).astype(int) ).flatten().reshape( (-1,2) )
            cv2.fillConvexPoly( hull_mask,hull,(1,1,1) )

        if self.mask_type == 'rect':
            image_mask = face_mask
        elif self.mask_type == 'faceHull':
            image_mask = hull_mask
        else:
            image_mask = ((face_mask*hull_mask))
            
        if self.erosion_kernel is not None:
            image_mask = cv2.erode(image_mask,self.erosion_kernel,iterations = 1)

        if self.blur_size!=0:
            image_mask = cv2.blur(image_mask,(self.blur_size,self.blur_size))

        return image_mask

# %% [markdown]
# 학습모델과 동일한 생성모델
# (load에서 weight가져오는 부분만 다름)

# %%
class Model():
    def __init__(self):

        self.model_dir = model_dir
        self.encoder = self.Encoder()
        self.decoder_A = self.Decoder()
        self.decoder_B = self.Decoder()

        self.initModel()

    def initModel(self):
        optimizer = Adam(lr=5e-5, beta_1=0.5, beta_2=0.999)
        x = Input(shape=IMAGE_SHAPE)

        self.autoencoder_A = KerasModel(x, self.decoder_A(self.encoder(x)))
        self.autoencoder_B = KerasModel(x, self.decoder_B(self.encoder(x)))

        self.autoencoder_A.compile(optimizer=optimizer, loss='mean_squared_error')
        self.autoencoder_B.compile(optimizer=optimizer, loss='mean_squared_error')

    def converter(self, swap):
        autoencoder = self.autoencoder_B if not swap else self.autoencoder_A
        return lambda img: autoencoder.predict(img)

    def conv(self, filters):
        def block(x):
            x = Conv2D(filters, kernel_size=5, strides=2, padding='same')(x)
            x = LeakyReLU(0.1)(x)
            return x
        return block

    def upscale(self, filters):
        def block(x):
            x = Conv2D(filters * 4, kernel_size=3, padding='same')(x)
            x = LeakyReLU(0.1)(x)
            x = PixelShuffler()(x)
            return x
        return block


    def Encoder(self):
        input_ = Input(shape=IMAGE_SHAPE)
        x = input_
        x = self.conv(128)(x)
        x = self.conv(256)(x)
        x = self.conv(512)(x)
        x = self.conv(1024)(x)
        x = Dense(ENCODER_DIM)(Flatten()(x))
        x = Dense(4 * 4 * 1024)(x)
        x = Reshape((4, 4, 1024))(x)
        x = self.upscale(512)(x)
        return KerasModel(input_, x)

    def Decoder(self):
        input_ = Input(shape=(8, 8, 512))
        x = input_
        x = self.upscale(256)(x)
        x = self.upscale(128)(x)
        x = self.upscale(64)(x)
        x = Conv2D(3, kernel_size=5, padding='same', activation='sigmoid')(x)
        return KerasModel(input_, x)

    def load(self, swapped):
        (face_A,face_B) = (decoder_AH5, decoder_BH5) if not swapped else (decoder_BH5, decoder_AH5)

        try:
            self.encoder.load_weights(self.model_dir + encoderH5)
            self.decoder_A.load_weights(self.model_dir + face_A)
            self.decoder_B.load_weights(self.model_dir + face_B)
            print('loaded model weights')
            return True
        except Exception as e:
            print('Failed loading existing training data.')
            print(e)
            return False

    def save_weights(self):
        self.encoder.save_weights(self.model_dir + encoderH5)
        self.decoder_A.save_weights(self.model_dir + decoder_AH5)
        self.decoder_B.save_weights(self.model_dir + decoder_BH5)
        print('saved model weights')

# %% [markdown]
# 3단계로 face swap 진행:
#     1. `PluginLoader.get_model(model_name)(model_dir)`을 통하여 모델 선언
#     2. 앞에서 학습한 모델 weights를 로딩
#     3. 입력 영상으로부터 얼굴의 특징을 `get_list_images_faces`를 이용하여 추출
#     4. `convert(converter, item)`를 통하여 모델을 호출하고 mask를 이용한 face swapping 수행

# %%
model = Model()
if not model.load(swap_model):
    print('Model Not Found! A valid model must be provided to continue!')
    exit(1)

faceswap_converter = PluginLoader.get_converter(conv_name)(model.converter(False),
    blur_size=blur_size,
    seamless_clone=seamless_clone,
    mask_type=mask_type,
    erosion_kernel_size=erosion_kernel_size,
    smooth_mask=smooth_mask,
    avg_color_adjust=avg_color_adjust
)

list_faces=get_list_images_faces()


batch = BackgroundGenerator(list_faces, 1)

for item in batch.iterator():
    convert(faceswap_converter, item)

# %%
# !ls test
# Out:
# bond.jpg				      CR_2012.jpg
# Casino-Royale-Eva-Green-Daniel-Craig.jpg      daniel-craig-casino-royale.jpg
# casino_royale_movie_image_james_bond__1_.jpg  james-bond-casino-royale.jpg
# Casino-Royale-Three-Piece-1000x524.jpg	      skyfall.jpg

# %%
import matplotlib.image as mp_image
import matplotlib.pyplot as plt

img_path = '048.jpg'
orgface = mp_image.imread('obama-jpg/'+img_path)
newface = mp_image.imread('test/'+img_path)
plt.figure(figsize=(12,8))
plt.subplot('121')
plt.imshow(orgface)
plt.subplot('122')
plt.imshow(newface)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-75-c4cd3b628975> in <module>
#       4 img_path = '048.jpg'
#       5 orgface = mp_image.imread('obama-jpg/'+img_path)
# ----> 6 newface = mp_image.imread('test/'+img_path)
#       7 plt.figure(figsize=(12,8))
#       8 plt.subplot('121')
#
# ~/anaconda3/envs/tensor/lib/python3.8/site-packages/matplotlib/image.py in imread(fname, format)
#    1499                     response = io.BytesIO(response.read())
#    1500                 return imread(response, format=ext)
# -> 1501     with img_open(fname) as image:
#    1502         return (_pil_png_to_float_array(image)
#    1503                 if isinstance(image, PIL.PngImagePlugin.PngImageFile) else
#
# ~/anaconda3/envs/tensor/lib/python3.8/site-packages/PIL/Image.py in open(fp, mode, formats)
#    2910
#    2911     if filename:
# -> 2912         fp = builtins.open(filename, "rb")
#    2913         exclusive_fp = True
#    2914
#
# FileNotFoundError: [Errno 2] No such file or directory: 'test/048.jpg'

# %% [markdown]
# **동영상 만들기 개요**
# 1. mp4 다운로드
# 2. ffmpeg을 이용하여 모든 frame 추출
#    `ffmpeg -i ../obama.mp4 file%04d.jpg`
# 3. faceswap 실행
# 4. 변환된 이미지를 다시 동영상으로 인코딩
#    `ffmpeg -framerate 29.97 -pattern_type glob -i '*.jpg' ../obama-swap.mp4`
